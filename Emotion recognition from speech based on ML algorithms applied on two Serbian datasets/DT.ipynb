# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score,recall_score,f1_score
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
def evaluation_classif_L(conf_mat):
    TP = conf_mat[0,0]
    FP = conf_mat[1,0]+conf_mat[2,0]+conf_mat[3,0]+conf_mat[4,0]
    FN = conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[0,4]
    TN = conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[1,4]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[2,4]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_N(conf_mat):
    TP = conf_mat[1,1]
    FP = conf_mat[0,1]+conf_mat[2,1]+conf_mat[3,1]+conf_mat[4,1]
    FN = conf_mat[1,0]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[1,4]
    TN = conf_mat[0,0]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[0,4]+conf_mat[2,0]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[2,4]+conf_mat[3,0]+conf_mat[3,2]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,0]+conf_mat[4,2]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_R(conf_mat):
    TP = conf_mat[2,2]
    FP = conf_mat[0,2]+conf_mat[1,2]+conf_mat[3,2]+conf_mat[4,2]
    FN = conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,3]+conf_mat[2,4]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,3]+conf_mat[0,4]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,3]+conf_mat[1,4]+conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_S(conf_mat):
    TP = conf_mat[3,3]
    FP = conf_mat[0,3]+conf_mat[1,3]+conf_mat[2,3]+conf_mat[4,3]
    FN = conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,4]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,4]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,4]+conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,4]+conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,4]
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_T(conf_mat):
    TP = conf_mat[4,4]
    FP = conf_mat[0,4]+conf_mat[1,4]+conf_mat[2,4]+conf_mat[3,4]
    FN = conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,3]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,3]
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
from google.colab import drive
drive.mount('/content/drive')
dataset_obuka_poc = pd.read_csv('drive/My Drive/diplomski2021/svi_preimenovani.csv')
#dataset_test = pd.read_csv('cookies_test.csv', header=0)
print(dataset_obuka_poc.shape)

dataset_obuka_poc.tail()
# Out:
# Mounted at /content/drive
# (9015, 386)
#                    name  pcm_RMSenergy_sma_max  ...  F0_sma_de_kurtosis  class
# 0  '1BMZD01L__1100.wav'               0.126734  ...            5.684139      ?
# 1  '1BMZD02L__1100.wav'               0.104423  ...            6.739047      ?
# 2  '1BMZD03L__1100.wav'               0.115782  ...            5.404254      ?
# 3  '1BMZD04L__1100.wav'               0.109434  ...            5.881023      ?
# 4  '1BMZD05L__1100.wav'               0.113291  ...            6.588470      ?
#
# [5 rows x 386 columns]

# %%
dataset_obuka_poc.loc[0:1752, 'class'] = 'L'
dataset_obuka_poc.loc[1753:3588, 'class'] = 'N'
dataset_obuka_poc.loc[3589:5341, 'class'] = 'R'
dataset_obuka_poc.loc[5342:7177, 'class'] = 'T'
dataset_obuka_poc.loc[7178:9016, 'class'] = 'S'

# %%
lista_izbaci = ['1052', '1101','1102','1103','1104','1105','1100']
indeksi_izbaci = []
for i in range(0, len(lista_izbaci)):    
    indeksi1 = dataset_obuka_poc.loc[dataset_obuka_poc['name'].str.find(lista_izbaci[i]) !=-1].index
    dataset_obuka_poc.drop(indeksi1, axis = 0, inplace = True)
dataset_obuka = dataset_obuka_poc
print(dataset_obuka.head())
print(dataset_obuka.shape)
# Out:
#                           name  ...  class
# 348  '1_0_0_MMMD01L__0001.wav'  ...      L
# 349  '1_0_0_MMMD01L__0002.wav'  ...      L
# 350  '1_0_0_MMMD01L__0003.wav'  ...      L
# 351  '1_0_0_MMMD01L__0005.wav'  ...      L
# 352  '1_0_0_MMMD01L__1003.wav'  ...      L
#
# [5 rows x 386 columns]
# (6937, 386)

# %%
X_obuka= dataset_obuka.iloc[:, :-1]
y_obuka = dataset_obuka.iloc[:, -1]

# %%
dataset_obuka.drop(['pcm_RMSenergy_sma_minPos','pcm_zcr_sma_maxPos','voiceProb_sma_minPos', 'F0_sma_min','F0_sma_minPos'],axis = 1,inplace = True)
print(dataset_obuka.shape)
# Out:
# (6937, 381)

# %%
bez_imena = dataset_obuka.drop(['name'], axis = 1)

# %%
X_obuka= bez_imena.iloc[:, :-1]
y_obuka = bez_imena.iloc[:, -1]

# %%
from sklearn.model_selection import GridSearchCV
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
parameters = {'criterion':('gini', 'entropy'), 'max_depth':[5, 10, 15,20], 'class_weight':(None, 'balanced')}
dt = DecisionTreeClassifier()
clf=GridSearchCV(dt, parameters,cv=kf)
clf.fit(X_std, y_obuka)
print(clf.best_score_)
print(clf.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d4ce41a97d23> in <module>()
#       4 dt = DecisionTreeClassifier()
#       5 clf=GridSearchCV(dt, parameters,cv=kf)
# ----> 6 clf.fit(X_std, y_obuka)
#       7 print(clf.best_score_)
#       8 print(clf.best_params_)
#
# NameError: name 'X_std' is not defined

# %%
labels_y = ['L', 'N', 'R', 'S', 'T']
s = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
     for m in [5,10,15,20,35]:
         for w in [None,'balanced']:
             indexes = kf.split(X_obuka, y_obuka)
             acc_tmp = []
             fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
             for train_index, test_index in indexes:
                 classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                 X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                 X_std_test = s.transform(X_obuka.iloc[test_index,:])
                 classifier.fit(X_std1, y_obuka.iloc[train_index])
                 y_pred = classifier.predict(X_std_test)
                 acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                 fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
             print('za parametre c=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
             print(fin_conf_mat)
             acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.6067475911856316  a mat. konf. je:
# [[ 751.  128.  221.  212.   34.]
#  [ 145.  809.  135.  201.  126.]
#  [ 225.  126.  784.  175.   36.]
#  [ 177.  196.  180.  764.   98.]
#  [  37.  124.   39.  113. 1101.]]
# Out:
# za parametre c= gini  i m= 5 weigth je: None  tacnost je:  0.5072844542585176  a mat. konf. je:
# [[659. 150. 182. 311.  44.]
#  [190. 519. 136. 450. 121.]
#  [248. 181. 601. 274.  42.]
#  [202. 155. 152. 804. 102.]
#  [ 39. 135.  27. 277. 936.]]
# za parametre c= gini  i m= 5 weigth je: balanced  tacnost je:  0.5039711649221735  a mat. konf. je:
# [[740. 121. 185. 247.  53.]
#  [248. 483. 141. 415. 129.]
#  [312. 156. 600. 238.  40.]
#  [291. 138. 153. 709. 124.]
#  [ 54. 125.  30. 241. 964.]]
# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5867131587592682  a mat. konf. je:
# [[ 712.  130.  224.  251.   29.]
#  [ 118.  795.  155.  218.  130.]
#  [ 208.  167.  710.  239.   22.]
#  [ 165.  190.  159.  812.   89.]
#  [  33.  155.   36.  149. 1041.]]
# za parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5815241754723022  a mat. konf. je:
# [[ 719.  126.  218.  264.   19.]
#  [ 142.  787.  141.  221.  125.]
#  [ 217.  137.  714.  246.   32.]
#  [ 210.  161.  159.  797.   88.]
#  [  35.  159.   40.  163. 1017.]]
# za parametre c= gini  i m= 15 weigth je: None  tacnost je:  0.5760438888680963  a mat. konf. je:
# [[ 731.  143.  228.  216.   28.]
#  [ 142.  779.  157.  199.  139.]
#  [ 217.  158.  716.  220.   35.]
#  [ 203.  182.  216.  715.   99.]
#  [  43.  147.   47.  122. 1055.]]
# za parametre c= gini  i m= 15 weigth je: balanced  tacnost je:  0.5782110940612382  a mat. konf. je:
# [[ 729.  122.  240.  226.   29.]
#  [ 149.  797.  142.  191.  137.]
#  [ 214.  153.  737.  204.   38.]
#  [ 202.  195.  210.  712.   96.]
#  [  50.  161.   40.  127. 1036.]]
# za parametre c= gini  i m= 20 weigth je: None  tacnost je:  0.572871364946293  a mat. konf. je:
# [[ 730.  143.  225.  211.   37.]
#  [ 148.  789.  146.  194.  139.]
#  [ 217.  175.  721.  196.   37.]
#  [ 211.  190.  210.  691.  113.]
#  [  50.  158.   44.  119. 1043.]]
# za parametre c= gini  i m= 20 weigth je: balanced  tacnost je:  0.5753223881465955  a mat. konf. je:
# [[ 729.  133.  234.  215.   35.]
#  [ 140.  806.  134.  194.  142.]
#  [ 214.  160.  731.  196.   45.]
#  [ 211.  187.  209.  687.  121.]
#  [  47.  168.   43.  118. 1038.]]
# za parametre c= gini  i m= 35 weigth je: None  tacnost je:  0.567973061200727  a mat. konf. je:
# [[ 723.  141.  231.  209.   42.]
#  [ 135.  776.  160.  203.  142.]
#  [ 213.  165.  717.  215.   36.]
#  [ 210.  188.  217.  693.  107.]
#  [  50.  163.   37.  133. 1031.]]
# za parametre c= gini  i m= 35 weigth je: balanced  tacnost je:  0.573016288866433  a mat. konf. je:
# [[ 712.  141.  239.  218.   36.]
#  [ 140.  802.  137.  204.  133.]
#  [ 212.  162.  736.  198.   38.]
#  [ 194.  197.  220.  687.  117.]
#  [  47.  165.   43.  121. 1038.]]
# za parametre c= entropy  i m= 5 weigth je: None  tacnost je:  0.5045442069937748  a mat. konf. je:
# [[519. 182. 232. 386.  27.]
#  [127. 571. 173. 382. 163.]
#  [239. 142. 667. 274.  24.]
#  [136. 238. 186. 746. 109.]
#  [ 14. 194.  31. 178. 997.]]
# za parametre c= entropy  i m= 5 weigth je: balanced  tacnost je:  0.5049814738575547  a mat. konf. je:
# [[ 576.  152.  230.  361.   27.]
#  [ 180.  522.  182.  366.  166.]
#  [ 281.  112.  679.  247.   27.]
#  [ 176.  204.  211.  714.  110.]
#  [  20.  172.   36.  174. 1012.]]
# za parametre c= entropy  i m= 10 weigth je: None  tacnost je:  0.5982326351202432  a mat. konf. je:
# [[ 735.  154.  221.  214.   22.]
#  [ 147.  818.  120.  199.  132.]
#  [ 221.  137.  757.  207.   24.]
#  [ 190.  201.  168.  766.   90.]
#  [  31.  149.   30.  130. 1074.]]
# za parametre c= entropy  i m= 10 weigth je: balanced  tacnost je:  0.6061656083269917  a mat. konf. je:
# [[ 738.  139.  229.  211.   29.]
#  [ 134.  804.  130.  215.  133.]
#  [ 221.  122.  791.  182.   30.]
#  [ 186.  201.  173.  775.   80.]
#  [  36.  139.   27.  115. 1097.]]
# za parametre c= entropy  i m= 15 weigth je: None  tacnost je:  0.5917503565918552  a mat. konf. je:
# [[ 745.  132.  217.  221.   31.]
#  [ 162.  778.  129.  197.  150.]
#  [ 232.  126.  764.  184.   40.]
#  [ 199.  195.  177.  741.  103.]
#  [  38.  136.   42.  121. 1077.]]
# za parametre c= entropy  i m= 15 weigth je: balanced  tacnost je:  0.6034311829700878  a mat. konf. je:
# [[ 733.  135.  224.  211.   43.]
#  [ 147.  800.  145.  197.  127.]
#  [ 225.  118.  789.  181.   33.]
#  [ 174.  199.  189.  753.  100.]
#  [  38.  133.   33.   99. 1111.]]
# za parametre c= entropy  i m= 20 weigth je: None  tacnost je:  0.5973718244611617  a mat. konf. je:
# [[ 755.  131.  217.  207.   36.]
#  [ 150.  797.  131.  192.  146.]
#  [ 217.  116.  771.  205.   37.]
#  [ 194.  195.  188.  723.  115.]
#  [  40.  135.   37.  104. 1098.]]
# za parametre c= entropy  i m= 20 weigth je: balanced  tacnost je:  0.6018455447850262  a mat. konf. je:
# [[ 738.  134.  229.  205.   40.]
#  [ 147.  806.  135.  201.  127.]
#  [ 237.  119.  773.  180.   37.]
#  [ 183.  196.  188.  756.   92.]
#  [  37.  132.   37.  106. 1102.]]
# za parametre c= entropy  i m= 35 weigth je: None  tacnost je:  0.5954975859874996  a mat. konf. je:
# [[ 760.  125.  212.  215.   34.]
#  [ 158.  806.  134.  180.  138.]
#  [ 249.  128.  756.  180.   33.]
#  [ 200.  194.  181.  724.  116.]
#  [  46.  131.   40.  112. 1085.]]
# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.6067475911856316  a mat. konf. je:
# [[ 751.  128.  221.  212.   34.]
#  [ 145.  809.  135.  201.  126.]
#  [ 225.  126.  784.  175.   36.]
#  [ 177.  196.  180.  764.   98.]
#  [  37.  124.   39.  113. 1101.]]
# najbolja tacnost je u iteraciji broj:  19

# %%
lista = ['0001','0002','0003','0005','1003','1004','1005','1007','1008','1009','1011','1012','1014','1015','1016','1023','1027','1036','1045','1051','1053','1057','1060']
indeksi_svi = []
for i in range(0,len(lista)):
    indeksi = dataset_obuka[dataset_obuka['name'].str.find(lista[i]) !=-1].index
    indeksi_svi.append(indeksi)
#print(indeksi_svi)

#dataset_obuka.drop(['name'],axis = 1, inplace = True)
for i in range(0,len(lista)): 
  bez_imena = dataset_obuka.drop(['name'], axis = 1)
  vars()["g"+lista[i]]= bez_imena.loc[indeksi_svi[i]]

# %%
baze = [g0001,g0002,g0003,g0005,g1003,g1004,g1005,g1007,g1008,g1009,g1011,g1012,g1014,g1015,g1016,g1023,g1027,g1036,g1045,g1051,g1053,g1057,g1060]
labels_y = ['L', 'N', 'R', 'S', 'T']
acc = []
fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
for i in range(0,len(baze)):
  izbaci = baze[i].index
  obuka = bez_imena.drop(izbaci, axis = 0)
  test = baze[i]

  acc_tmp = []
  X_obuka29= obuka.iloc[:, :-1]
  y_obuka29 = obuka.iloc[:, -1]
  s = StandardScaler()
  X_obuka29_std = s.fit_transform(X_obuka29)

  X_test1= test.iloc[:, :-1]
  y_test1 = test.iloc[:, -1]
  X_test1_std = s.transform(X_test1)

  classifier_kon = DecisionTreeClassifier(class_weight='balanced',criterion='entropy',max_depth=10)  
  classifier_kon.fit(X_obuka29_std, y_obuka29)

  # testiranje
  y_pred_kon = classifier_kon.predict(X_test1_std) 
  #navedi tacne nazive umesto y_test1
  conf_mat_dt1 = confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  #print(conf_mat_knnSZ)
  
  #acc_tmp.append(accuracy_score(y_test1, y_pred_kon))
  fin_conf_mat += confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  
  print(fin_conf_mat)

# [[457. 212. 353. 247.  77.]
#  [291. 373. 186. 335. 231.]
#  [257. 173. 549. 277.  90.]
#  [285. 234. 228. 499. 169.]
#  [ 66. 327.  85. 239. 697.]]
# Out:
# [[25.  0. 31.  1.  0.]
#  [14.  6. 26. 12.  2.]
#  [ 4.  0. 53.  0.  0.]
#  [ 4.  7. 14. 32.  3.]
#  [ 4. 10.  4. 30. 12.]]
# [[37. 20. 49.  6.  2.]
#  [23. 18. 37. 32. 10.]
#  [ 9. 14. 82.  9.  0.]
#  [ 6. 32. 30. 45.  7.]
#  [10. 23.  7. 54. 26.]]
# [[ 43.  26.  91.   9.   2.]
#  [ 26.  46.  45.  40.  23.]
#  [ 15.  19. 124.  13.   0.]
#  [ 11.  47.  46.  55.  21.]
#  [ 10.  33.   8.  56.  73.]]
# [[ 73.  27. 107.  19.   2.]
#  [ 68.  47.  55.  47.  23.]
#  [ 36.  19. 153.  20.   0.]
#  [ 46.  47.  51.  75.  21.]
#  [ 10.  56.   9.  60. 105.]]
# [[105.  39. 114.  24.   3.]
#  [ 97.  58.  65.  54.  26.]
#  [ 59.  34. 162.  29.   1.]
#  [ 78.  62.  55.  84.  21.]
#  [ 13.  68.   9.  61. 149.]]
# [[117.  53. 119.  50.   5.]
#  [115.  75.  68.  75.  29.]
#  [ 72.  37. 175.  56.   4.]
#  [ 81.  79.  56. 122.  24.]
#  [ 14. 110.   9.  75. 154.]]
# [[140.  58. 127.  73.   5.]
#  [120. 100.  68. 105.  31.]
#  [ 75.  41. 191.  89.   7.]
#  [ 84.  85.  59. 172.  24.]
#  [ 20. 136.  18.  83. 167.]]
# [[166.  62. 147.  82.   5.]
#  [124. 105.  70. 147.  40.]
#  [ 91.  41. 231.  92.   7.]
#  [ 99.  92.  63. 200.  32.]
#  [ 21. 138.  18.  83. 226.]]
# [[191.  77. 157.  91.   5.]
#  [162. 112.  80. 152.  42.]
#  [105.  46. 264.  98.   8.]
#  [117.  95.  90. 211.  35.]
#  [ 22. 162.  23.  85. 256.]]
# [[208.  77. 188. 101.   6.]
#  [168. 126. 100. 166.  50.]
#  [120.  47. 299. 100.  14.]
#  [123.  98. 119. 230.  40.]
#  [ 22. 165.  24.  92. 307.]]
# [[240.  82. 206. 105.   6.]
#  [169. 147. 102. 185.  69.]
#  [130.  56. 332. 107.  14.]
#  [135. 108. 127. 262.  40.]
#  [ 24. 189.  46. 101. 312.]]
# [[257.  95. 216. 118.  11.]
#  [180. 174. 113. 193.  74.]
#  [145.  67. 350. 119.  16.]
#  [152. 126. 136. 278.  41.]
#  [ 26. 195.  61. 110. 340.]]
# [[283. 115. 227. 120.  11.]
#  [188. 202. 115. 206.  85.]
#  [155.  74. 365. 145.  17.]
#  [166. 132. 142. 314.  41.]
#  [ 26. 215.  61. 132. 360.]]
# [[296. 115. 267. 126.  11.]
#  [219. 205. 136. 213.  85.]
#  [163.  74. 413. 148.  17.]
#  [186. 136. 166. 328.  41.]
#  [ 29. 226.  62. 151. 388.]]
# [[315. 117. 279. 152.  11.]
#  [223. 212. 137. 228. 120.]
#  [170.  85. 424. 167.  28.]
#  [204. 142. 174. 344.  55.]
#  [ 31. 229.  67. 163. 428.]]
# [[330. 141. 299. 152.  11.]
#  [229. 256. 141. 234. 122.]
#  [182. 116. 437. 170.  28.]
#  [223. 153. 194. 356.  55.]
#  [ 34. 250.  68. 169. 459.]]
# [[336. 149. 299. 159.  49.]
#  [230. 281. 141. 242. 150.]
#  [184. 123. 437. 180.  68.]
#  [223. 158. 194. 358. 110.]
#  [ 34. 251.  68. 169. 520.]]
# [[375. 149. 308. 170.  49.]
#  [252. 289. 159. 256. 150.]
#  [202. 127. 459. 195.  68.]
#  [242. 166. 201. 386. 110.]
#  [ 55. 263.  75. 185. 526.]]
# [[398. 150. 333. 180.  49.]
#  [268. 298. 178. 273. 151.]
#  [205. 127. 513. 197.  68.]
#  [251. 167. 218. 419. 112.]
#  [ 55. 270.  80. 188. 573.]]
# [[403. 187. 338. 184.  57.]
#  [268. 334. 180. 276. 172.]
#  [211. 148. 533. 204.  73.]
#  [252. 198. 227. 428. 124.]
#  [ 55. 289.  83. 192. 609.]]
# [[408. 201. 347. 202.  70.]
#  [268. 349. 186. 285. 204.]
#  [212. 167. 541. 224.  84.]
#  [254. 216. 227. 438. 156.]
#  [ 56. 302.  84. 199. 649.]]
# [[411. 206. 351. 243.  76.]
#  [268. 373. 186. 298. 229.]
#  [213. 170. 547. 269.  88.]
#  [254. 222. 228. 486. 163.]
#  [ 56. 324.  85. 205. 682.]]
# [[457. 212. 353. 247.  77.]
#  [291. 373. 186. 335. 231.]
#  [257. 173. 549. 277.  90.]
#  [285. 234. 228. 499. 169.]
#  [ 66. 327.  85. 239. 697.]]

# %%
L = evaluation_classif_L(fin_conf_mat)
N = evaluation_classif_N(fin_conf_mat)
R = evaluation_classif_R(fin_conf_mat)
S = evaluation_classif_S(fin_conf_mat)
T = evaluation_classif_T(fin_conf_mat)

print(fin_conf_mat)

prosecna_tacnost = (L[0]+N[0]+R[0]+S[0]+T[0])/5
print('PROSECNA TACNOST DT JE ', prosecna_tacnost)

prosecna_specificnost = (L[3]+N[3]+R[3]+S[3]+T[3])/5
print('PROSECNA specificnost DT JE ', prosecna_specificnost)

prosecna_preciznost = (L[1]+N[1]+R[1]+S[1]+T[1])/5
print('PROSECNA preciznost DT JE ', prosecna_preciznost)

prosecna_osetljivost = (L[2]+N[2]+R[2]+S[2]+T[2])/5
print('PROSECNA osetljivost DT JE ', prosecna_osetljivost)

# PROSECNA TACNOST DT JE  0.748479169669886
# PROSECNA specificnost DT JE  0.8427939466457977
# PROSECNA preciznost DT JE  0.3751117022342615
# PROSECNA osetljivost DT JE  0.37127916456253257
# Out:
# [[457. 212. 353. 247.  77.]
#  [291. 373. 186. 335. 231.]
#  [257. 173. 549. 277.  90.]
#  [285. 234. 228. 499. 169.]
#  [ 66. 327.  85. 239. 697.]]
# PROSECNA TACNOST DT JE  0.748479169669886
# PROSECNA specificnost DT JE  0.8427939466457977
# PROSECNA preciznost DT JE  0.3751117022342615
# PROSECNA osetljivost DT JE  0.37127916456253257

# %%
#PCA -TRAZENJE OPTIMALNIH PARAMETARA ZA n=125
labels_y = ['L', 'N', 'R', 'S', 'T']
s = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
     for m in [5,10,15,20,35]:
         for w in [None,'balanced']:
             indexes = kf.split(X_obuka, y_obuka)
             acc_tmp = []
             fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
             for train_index, test_index in indexes:
                 X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                 X_std_test = s.transform(X_obuka.iloc[test_index,:])
                 pca = PCA(n_components=125)
                 pca.fit(X_std1)
                 X_train_r = pca.transform(X_std1)
                 X_test_r=pca.transform(X_std_test)
                 classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                 classifier.fit(X_train_r, y_obuka.iloc[train_index])
                 y_pred = classifier.predict(X_test_r)
                 acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                 fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
             print('za parametre c=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
             print(fin_conf_mat)
             acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za n=125 parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.533517763056668  a mat. konf. je:
# [[676. 151. 236. 236.  47.]
#  [186. 660. 168. 254. 148.]
#  [224. 164. 730. 188.  40.]
#  [203. 200. 220. 656. 136.]
#  [ 66. 159.  44. 166. 979.]]
# Out:
# za parametre c= gini  i m= 5 weigth je: None  tacnost je:  0.4595695530854032  a mat. konf. je:
# [[541. 254. 333. 178.  40.]
#  [191. 595. 195. 279. 156.]
#  [282. 236. 678. 123.  27.]
#  [214. 332. 271. 465. 133.]
#  [ 44. 222.  51. 188. 909.]]
# za parametre c= gini  i m= 5 weigth je: balanced  tacnost je:  0.45740650639786085  a mat. konf. je:
# [[545. 221. 368. 174.  38.]
#  [221. 565. 223. 260. 147.]
#  [266. 223. 724. 109.  24.]
#  [234. 320. 294. 439. 128.]
#  [ 50. 220.  62. 182. 900.]]
# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5267450129121599  a mat. konf. je:
# [[664. 173. 227. 223.  59.]
#  [199. 694. 149. 233. 141.]
#  [266. 193. 684. 172.  31.]
#  [231. 211. 203. 654. 116.]
#  [ 63. 179.  40. 174. 958.]]
# za parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.533517763056668  a mat. konf. je:
# [[676. 151. 236. 236.  47.]
#  [186. 660. 168. 254. 148.]
#  [224. 164. 730. 188.  40.]
#  [203. 200. 220. 656. 136.]
#  [ 66. 159.  44. 166. 979.]]
# za parametre c= gini  i m= 15 weigth je: None  tacnost je:  0.51693343480087  a mat. konf. je:
# [[615. 163. 274. 223.  71.]
#  [185. 674. 158. 242. 157.]
#  [226. 180. 685. 206.  49.]
#  [225. 200. 200. 633. 157.]
#  [ 54. 197.  39. 145. 979.]]
# za parametre c= gini  i m= 15 weigth je: balanced  tacnost je:  0.5179474863912904  a mat. konf. je:
# [[622. 161. 263. 231.  69.]
#  [173. 679. 175. 232. 157.]
#  [239. 158. 705. 199.  45.]
#  [207. 220. 214. 623. 151.]
#  [ 78. 167.  41. 164. 964.]]
# za parametre c= gini  i m= 20 weigth je: None  tacnost je:  0.5133348719804051  a mat. konf. je:
# [[621. 170. 256. 230.  69.]
#  [187. 656. 170. 235. 168.]
#  [221. 145. 702. 221.  57.]
#  [227. 199. 200. 621. 168.]
#  [ 58. 178.  42. 175. 961.]]
# za parametre c= gini  i m= 20 weigth je: balanced  tacnost je:  0.5067033031009975  a mat. konf. je:
# [[625. 168. 258. 239.  56.]
#  [187. 635. 204. 221. 169.]
#  [236. 176. 678. 211.  45.]
#  [226. 187. 216. 612. 174.]
#  [ 77. 160.  55. 157. 965.]]
# za parametre c= gini  i m= 35 weigth je: None  tacnost je:  0.5104528196747217  a mat. konf. je:
# [[610. 167. 269. 220.  80.]
#  [163. 684. 163. 236. 170.]
#  [243. 168. 678. 208.  49.]
#  [219. 212. 197. 632. 155.]
#  [ 74. 183.  46. 174. 937.]]
# za parametre c= gini  i m= 35 weigth je: balanced  tacnost je:  0.5149175992115473  a mat. konf. je:
# [[639. 168. 239. 234.  66.]
#  [191. 663. 176. 220. 166.]
#  [227. 169. 671. 223.  56.]
#  [222. 200. 209. 628. 156.]
#  [ 68. 166.  49. 160. 971.]]
# za parametre c= entropy  i m= 5 weigth je: None  tacnost je:  0.4611520723912655  a mat. konf. je:
# [[ 582.  200.  283.  222.   59.]
#  [ 208.  578.  159.  233.  238.]
#  [ 382.  165.  593.  128.   78.]
#  [ 258.  302.  235.  432.  188.]
#  [  57.  180.   48.  115. 1014.]]
# za parametre c= entropy  i m= 5 weigth je: balanced  tacnost je:  0.4610065246952854  a mat. konf. je:
# [[ 598.  190.  299.  191.   68.]
#  [ 213.  566.  160.  217.  260.]
#  [ 378.  171.  597.  128.   72.]
#  [ 267.  314.  240.  397.  197.]
#  [  62.  153.   51.  108. 1040.]]
# za parametre c= entropy  i m= 10 weigth je: None  tacnost je:  0.5294819333724232  a mat. konf. je:
# [[620. 180. 266. 225.  55.]
#  [184. 684. 175. 234. 139.]
#  [245. 161. 731. 182.  27.]
#  [248. 216. 184. 643. 124.]
#  [ 70. 152.  31. 166. 995.]]
# za parametre c= entropy  i m= 10 weigth je: balanced  tacnost je:  0.5232867996556758  a mat. konf. je:
# [[608. 185. 257. 242.  54.]
#  [187. 677. 164. 255. 133.]
#  [270. 135. 711. 184.  46.]
#  [239. 213. 194. 645. 124.]
#  [ 59. 164.  43. 159. 989.]]
# za parametre c= entropy  i m= 15 weigth je: None  tacnost je:  0.5235745682431561  a mat. konf. je:
# [[622. 159. 257. 246.  62.]
#  [168. 674. 155. 263. 156.]
#  [250. 160. 693. 202.  41.]
#  [214. 223. 194. 653. 131.]
#  [ 69. 162.  37. 156. 990.]]
# za parametre c= entropy  i m= 15 weigth je: balanced  tacnost je:  0.5218519072985932  a mat. konf. je:
# [[625. 172. 258. 223.  68.]
#  [175. 683. 153. 236. 169.]
#  [243. 157. 690. 217.  39.]
#  [208. 216. 216. 636. 139.]
#  [ 60. 157.  42. 169. 986.]]
# za parametre c= entropy  i m= 20 weigth je: None  tacnost je:  0.5302073846742436  a mat. konf. je:
# [[ 623.  157.  237.  259.   70.]
#  [ 175.  691.  156.  215.  179.]
#  [ 228.  158.  701.  225.   34.]
#  [ 223.  203.  176.  659.  154.]
#  [  54.  149.   47.  160. 1004.]]
# za parametre c= entropy  i m= 20 weigth je: balanced  tacnost je:  0.5175276852510282  a mat. konf. je:
# [[626. 175. 241. 237.  67.]
#  [180. 661. 157. 274. 144.]
#  [246. 158. 694. 209.  39.]
#  [241. 211. 196. 638. 129.]
#  [ 70. 150.  35. 188. 971.]]
# za parametre c= entropy  i m= 35 weigth je: None  tacnost je:  0.5203985095915932  a mat. konf. je:
# [[625. 184. 251. 233.  53.]
#  [173. 675. 156. 245. 167.]
#  [226. 182. 688. 214.  36.]
#  [234. 211. 187. 639. 144.]
#  [ 59. 165.  46. 161. 983.]]
# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.5178098398559494  a mat. konf. je:
# [[617. 183. 265. 224.  57.]
#  [178. 681. 167. 229. 161.]
#  [246. 147. 701. 213.  39.]
#  [245. 208. 194. 623. 145.]
#  [ 65. 159.  46. 174. 970.]]
# najbolja tacnost je u iteraciji broj:  3

# %%
#PCA -TRAZENJE OPTIMALNIH PARAMETARA ZA n=150
labels_y = ['L', 'N', 'R', 'S', 'T']
s = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
     for m in [5,10,15,20,35]:
         for w in [None,'balanced']:
             indexes = kf.split(X_obuka, y_obuka)
             acc_tmp = []
             fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
             for train_index, test_index in indexes:
                 X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                 X_std_test = s.transform(X_obuka.iloc[test_index,:])
                 pca = PCA(n_components=150)
                 pca.fit(X_std1)
                 X_train_r = pca.transform(X_std1)
                 X_test_r=pca.transform(X_std_test)
                 classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                 classifier.fit(X_train_r, y_obuka.iloc[train_index])
                 y_pred = classifier.predict(X_test_r)
                 acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                 fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
             print('za parametre c=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
             print(fin_conf_mat)
             acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za N = 150 parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5251560479226186  a mat. konf. je:
# [[666. 142. 244. 251.  43.]
#  [194. 654. 171. 256. 141.]
#  [256. 167. 710. 178.  35.]
#  [227. 196. 217. 648. 127.]
#  [ 58. 163.  53. 175. 965.]]
# Out:
# za parametre c= gini  i m= 5 weigth je: None  tacnost je:  0.4579845386761813  a mat. konf. je:
# [[535. 254. 335. 182.  40.]
#  [190. 594. 196. 280. 156.]
#  [280. 236. 678. 124.  28.]
#  [217. 332. 273. 461. 132.]
#  [ 45. 222.  51. 187. 909.]]
# za parametre c= gini  i m= 5 weigth je: balanced  tacnost je:  0.45668604530275997  a mat. konf. je:
# [[540. 222. 371. 174.  39.]
#  [216. 569. 224. 260. 147.]
#  [266. 223. 725. 108.  24.]
#  [233. 323. 297. 434. 128.]
#  [ 49. 221.  62. 182. 900.]]
# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5214106898544938  a mat. konf. je:
# [[655. 159. 247. 240.  45.]
#  [188. 686. 164. 239. 139.]
#  [258. 181. 691. 182.  34.]
#  [227. 203. 219. 644. 122.]
#  [ 54. 197.  48. 174. 941.]]
# za parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5251560479226186  a mat. konf. je:
# [[666. 142. 244. 251.  43.]
#  [194. 654. 171. 256. 141.]
#  [256. 167. 710. 178.  35.]
#  [227. 196. 217. 648. 127.]
#  [ 58. 163.  53. 175. 965.]]
# za parametre c= gini  i m= 15 weigth je: None  tacnost je:  0.5120384578597836  a mat. konf. je:
# [[621. 176. 247. 230.  72.]
#  [197. 662. 170. 228. 159.]
#  [246. 172. 669. 209.  50.]
#  [241. 202. 214. 621. 137.]
#  [ 64. 173.  53. 145. 979.]]
# za parametre c= gini  i m= 15 weigth je: balanced  tacnost je:  0.5090079469042005  a mat. konf. je:
# [[606. 167. 279. 230.  64.]
#  [166. 657. 175. 252. 166.]
#  [264. 154. 682. 195.  51.]
#  [237. 191. 206. 624. 157.]
#  [ 67. 165.  58. 162. 962.]]
# za parametre c= gini  i m= 20 weigth je: None  tacnost je:  0.5077140278869385  a mat. konf. je:
# [[631. 162. 228. 259.  66.]
#  [162. 656. 167. 251. 180.]
#  [264. 181. 658. 196.  47.]
#  [218. 227. 206. 619. 145.]
#  [ 67. 169.  50. 170. 958.]]
# za parametre c= gini  i m= 20 weigth je: balanced  tacnost je:  0.5072775927242786  a mat. konf. je:
# [[616. 170. 259. 249.  52.]
#  [198. 656. 159. 231. 172.]
#  [261. 156. 681. 202.  46.]
#  [226. 214. 194. 613. 168.]
#  [ 71. 162.  51. 177. 953.]]
# za parametre c= gini  i m= 35 weigth je: None  tacnost je:  0.5105935850892622  a mat. konf. je:
# [[628. 174. 271. 208.  65.]
#  [184. 668. 165. 243. 156.]
#  [261. 162. 668. 203.  52.]
#  [223. 212. 209. 626. 145.]
#  [ 61. 191.  49. 161. 952.]]
# za parametre c= gini  i m= 35 weigth je: balanced  tacnost je:  0.5006447762931913  a mat. konf. je:
# [[588. 190. 285. 212.  71.]
#  [190. 669. 154. 232. 171.]
#  [253. 173. 664. 193.  63.]
#  [234. 219. 214. 604. 144.]
#  [ 68. 178.  38. 182. 948.]]
# za parametre c= entropy  i m= 5 weigth je: None  tacnost je:  0.4592767942912036  a mat. konf. je:
# [[ 583.  199.  283.  222.   59.]
#  [ 219.  567.  159.  233.  238.]
#  [ 382.  165.  593.  128.   78.]
#  [ 258.  302.  235.  431.  189.]
#  [  58.  180.   48.  116. 1012.]]
# za parametre c= entropy  i m= 5 weigth je: balanced  tacnost je:  0.46057404011294495  a mat. konf. je:
# [[ 597.  191.  299.  191.   68.]
#  [ 214.  565.  160.  217.  260.]
#  [ 378.  171.  597.  128.   72.]
#  [ 270.  311.  240.  397.  197.]
#  [  63.  152.   51.  109. 1039.]]
# za parametre c= entropy  i m= 10 weigth je: None  tacnost je:  0.5250138270311181  a mat. konf. je:
# [[645. 169. 251. 231.  50.]
#  [176. 683. 161. 253. 143.]
#  [249. 148. 731. 186.  32.]
#  [248. 226. 181. 630. 130.]
#  [ 69. 154.  42. 196. 953.]]
# za parametre c= entropy  i m= 10 weigth je: balanced  tacnost je:  0.5191056302007311  a mat. konf. je:
# [[620. 179. 255. 240.  52.]
#  [195. 676. 169. 235. 141.]
#  [278. 146. 708. 183.  31.]
#  [238. 230. 212. 624. 111.]
#  [ 73. 159.  36. 173. 973.]]
# za parametre c= entropy  i m= 15 weigth je: None  tacnost je:  0.5137760894245044  a mat. konf. je:
# [[625. 164. 250. 247.  60.]
#  [169. 654. 170. 240. 183.]
#  [247. 161. 684. 208.  46.]
#  [237. 216. 194. 634. 134.]
#  [ 67. 170.  42. 168. 967.]]
# za parametre c= entropy  i m= 15 weigth je: balanced  tacnost je:  0.5111784789018218  a mat. konf. je:
# [[613. 182. 248. 240.  63.]
#  [189. 654. 166. 252. 155.]
#  [251. 152. 685. 208.  50.]
#  [265. 211. 185. 617. 137.]
#  [ 71. 156.  51. 159. 977.]]
# za parametre c= entropy  i m= 20 weigth je: None  tacnost je:  0.522710430779595  a mat. konf. je:
# [[636. 155. 253. 236.  66.]
#  [153. 691. 167. 237. 168.]
#  [230. 157. 694. 230.  35.]
#  [230. 225. 195. 631. 134.]
#  [ 71. 166.  35. 168. 974.]]
# za parametre c= entropy  i m= 20 weigth je: balanced  tacnost je:  0.5140634421614249  a mat. konf. je:
# [[622. 169. 254. 234.  67.]
#  [180. 676. 161. 250. 149.]
#  [256. 151. 675. 223.  41.]
#  [237. 211. 215. 611. 141.]
#  [ 59. 149.  43. 181. 982.]]
# za parametre c= entropy  i m= 35 weigth je: None  tacnost je:  0.5178077606031497  a mat. konf. je:
# [[619. 155. 250. 255.  67.]
#  [170. 687. 159. 234. 166.]
#  [233. 158. 695. 218.  42.]
#  [249. 208. 188. 624. 146.]
#  [ 68. 171.  48. 160. 967.]]
# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.5120440718423427  a mat. konf. je:
# [[605. 161. 271. 238.  71.]
#  [174. 683. 156. 236. 167.]
#  [246. 152. 679. 216.  53.]
#  [234. 229. 212. 596. 144.]
#  [ 68. 155.  40. 162. 989.]]
# najbolja tacnost je u iteraciji broj:  3

# %%
#PCA -TRAZENJE OPTIMALNIH PARAMETARA ZA n=175
labels_y = ['L', 'N', 'R', 'S', 'T']
s = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
     for m in [5,10,15,20,35]:
         for w in [None,'balanced']:
             indexes = kf.split(X_obuka, y_obuka)
             acc_tmp = []
             fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
             for train_index, test_index in indexes:
                 X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                 X_std_test = s.transform(X_obuka.iloc[test_index,:])
                 pca = PCA(n_components=175)
                 pca.fit(X_std1)
                 X_train_r = pca.transform(X_std1)
                 X_test_r=pca.transform(X_std_test)
                 classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                 classifier.fit(X_train_r, y_obuka.iloc[train_index])
                 y_pred = classifier.predict(X_test_r)
                 acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                 fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
             print('za parametre c=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
             print(fin_conf_mat)
             acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5211214657900537  a mat. konf. je:
# [[656. 140. 247. 259.  44.]
#  [185. 679. 168. 258. 126.]
#  [255. 193. 688. 175.  35.]
#  [209. 222. 211. 653. 120.]
#  [ 63. 180.  46. 186. 939.]]
# Out:
# za parametre c= gini  i m= 5 weigth je: None  tacnost je:  0.4587047918460022  a mat. konf. je:
# [[541. 254. 334. 177.  40.]
#  [192. 593. 195. 279. 157.]
#  [282. 236. 678. 123.  27.]
#  [214. 332. 273. 463. 133.]
#  [ 44. 222.  51. 190. 907.]]
# za parametre c= gini  i m= 5 weigth je: balanced  tacnost je:  0.45639786086471973  a mat. konf. je:
# [[544. 221. 368. 174.  39.]
#  [221. 565. 223. 260. 147.]
#  [267. 223. 724. 108.  24.]
#  [237. 320. 294. 436. 128.]
#  [ 50. 222.  62. 183. 897.]]
# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5211214657900537  a mat. konf. je:
# [[656. 140. 247. 259.  44.]
#  [185. 679. 168. 258. 126.]
#  [255. 193. 688. 175.  35.]
#  [209. 222. 211. 653. 120.]
#  [ 63. 180.  46. 186. 939.]]
# za parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5166537752993084  a mat. konf. je:
# [[642. 130. 263. 261.  50.]
#  [207. 663. 154. 248. 144.]
#  [238. 156. 714. 199.  39.]
#  [225. 202. 226. 621. 141.]
#  [ 63. 171.  56. 180. 944.]]
# za parametre c= gini  i m= 15 weigth je: None  tacnost je:  0.5067037189515575  a mat. konf. je:
# [[621. 159. 262. 235.  69.]
#  [178. 668. 180. 226. 164.]
#  [243. 200. 655. 198.  50.]
#  [225. 222. 206. 613. 149.]
#  [ 77. 173.  42. 164. 958.]]
# za parametre c= gini  i m= 15 weigth je: balanced  tacnost je:  0.5022335333574526  a mat. konf. je:
# [[616. 153. 255. 253.  69.]
#  [172. 656. 179. 237. 172.]
#  [252. 176. 673. 196.  49.]
#  [218. 205. 237. 587. 168.]
#  [ 74. 170.  51. 167. 952.]]
# za parametre c= gini  i m= 20 weigth je: None  tacnost je:  0.5026637307617134  a mat. konf. je:
# [[637. 159. 249. 222.  79.]
#  [177. 668. 174. 220. 177.]
#  [258. 184. 634. 216.  54.]
#  [251. 209. 196. 604. 155.]
#  [ 79. 167.  49. 175. 944.]]
# za parametre c= gini  i m= 20 weigth je: balanced  tacnost je:  0.4987771914284882  a mat. konf. je:
# [[594. 180. 265. 240.  67.]
#  [194. 631. 191. 238. 162.]
#  [257. 163. 674. 198.  54.]
#  [213. 200. 224. 617. 161.]
#  [ 74. 173.  54. 169. 944.]]
# za parametre c= gini  i m= 35 weigth je: None  tacnost je:  0.49488399848630404  a mat. konf. je:
# [[576. 169. 277. 246.  78.]
#  [170. 643. 193. 236. 174.]
#  [248. 185. 649. 216.  48.]
#  [243. 216. 190. 617. 149.]
#  [ 68. 178.  63. 157. 948.]]
# za parametre c= gini  i m= 35 weigth je: balanced  tacnost je:  0.4986291486291486  a mat. konf. je:
# [[590. 162. 266. 259.  69.]
#  [200. 636. 170. 240. 170.]
#  [253. 174. 669. 203.  47.]
#  [221. 224. 205. 624. 141.]
#  [ 55. 199.  55. 165. 940.]]
# za parametre c= entropy  i m= 5 weigth je: None  tacnost je:  0.46129595668500567  a mat. konf. je:
# [[ 586.  196.  283.  222.   59.]
#  [ 209.  577.  159.  233.  238.]
#  [ 382.  165.  593.  128.   78.]
#  [ 261.  299.  235.  431.  189.]
#  [  58.  179.   48.  116. 1013.]]
# za parametre c= entropy  i m= 5 weigth je: balanced  tacnost je:  0.46028585567490465  a mat. konf. je:
# [[ 597.  191.  299.  191.   68.]
#  [ 214.  564.  161.  217.  260.]
#  [ 378.  171.  597.  128.   72.]
#  [ 270.  311.  240.  397.  197.]
#  [  65.  152.   51.  108. 1038.]]
# za parametre c= entropy  i m= 10 weigth je: None  tacnost je:  0.51794998149465  a mat. konf. je:
# [[615. 182. 265. 236.  48.]
#  [172. 689. 161. 250. 144.]
#  [266. 162. 698. 183.  37.]
#  [245. 224. 186. 633. 127.]
#  [ 67. 155.  39. 195. 958.]]
# za parametre c= entropy  i m= 10 weigth je: balanced  tacnost je:  0.5160780301990677  a mat. konf. je:
# [[626. 179. 272. 214.  55.]
#  [193. 663. 170. 242. 148.]
#  [261. 148. 707. 190.  40.]
#  [250. 210. 214. 598. 143.]
#  [ 72. 156.  37. 163. 986.]]
# za parametre c= entropy  i m= 15 weigth je: None  tacnost je:  0.5169475737199081  a mat. konf. je:
# [[597. 167. 280. 242.  60.]
#  [159. 690. 175. 229. 163.]
#  [231. 181. 698. 198.  38.]
#  [235. 230. 195. 607. 148.]
#  [ 61. 161.  33. 165. 994.]]
# za parametre c= entropy  i m= 15 weigth je: balanced  tacnost je:  0.5136332447571641  a mat. konf. je:
# [[610. 174. 254. 237.  71.]
#  [177. 665. 170. 257. 147.]
#  [243. 161. 686. 210.  46.]
#  [244. 223. 188. 624. 136.]
#  [ 69. 162.  39. 166. 978.]]
# za parametre c= entropy  i m= 20 weigth je: None  tacnost je:  0.5130516777490841  a mat. konf. je:
# [[627. 170. 246. 250.  53.]
#  [180. 665. 168. 237. 166.]
#  [241. 166. 693. 206.  40.]
#  [238. 233. 201. 604. 139.]
#  [ 63. 165.  42. 174. 970.]]
# za parametre c= entropy  i m= 20 weigth je: balanced  tacnost je:  0.5205505029712523  a mat. konf. je:
# [[619. 162. 272. 235.  58.]
#  [164. 689. 168. 235. 160.]
#  [251. 160. 694. 197.  44.]
#  [228. 224. 193. 626. 144.]
#  [ 66. 149.  55. 161. 983.]]
# za parametre c= entropy  i m= 35 weigth je: None  tacnost je:  0.515646793168407  a mat. konf. je:
# [[641. 155. 247. 236.  67.]
#  [179. 644. 163. 254. 176.]
#  [237. 161. 711. 191.  46.]
#  [254. 226. 184. 613. 138.]
#  [ 66. 154.  39. 187. 968.]]
# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.513487489135904  a mat. konf. je:
# [[610. 177. 248. 251.  60.]
#  [168. 673. 156. 247. 172.]
#  [246. 177. 671. 205.  47.]
#  [216. 237. 192. 630. 140.]
#  [ 62. 153.  48. 173. 978.]]
# najbolja tacnost je u iteraciji broj:  2

# %%
#PCA -TRAZENJE OPTIMALNIH PARAMETARA ZA n=200
labels_y = ['L', 'N', 'R', 'S', 'T']
s = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
     for m in [5,10,15,20,35]:
         for w in [None,'balanced']:
             indexes = kf.split(X_obuka, y_obuka)
             acc_tmp = []
             fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
             for train_index, test_index in indexes:
                 X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                 X_std_test = s.transform(X_obuka.iloc[test_index,:])
                 pca = PCA(n_components=200)
                 pca.fit(X_std1)
                 X_train_r = pca.transform(X_std1)
                 X_test_r=pca.transform(X_std_test)
                 classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                 classifier.fit(X_train_r, y_obuka.iloc[train_index])
                 y_pred = classifier.predict(X_test_r)
                 acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                 fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
             print('za parametre c=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
             print(fin_conf_mat)
             acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za n=200 parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5225609325032956  a mat. konf. je:
# [[662. 143. 239. 252.  50.]
#  [204. 646. 159. 253. 154.]
#  [232. 174. 718. 181.  41.]
#  [211. 200. 225. 651. 128.]
#  [ 53. 172.  49. 192. 948.]]
# Out:
# za parametre c= gini  i m= 5 weigth je: None  tacnost je:  0.45928116072208286  a mat. konf. je:
# [[540. 264. 333. 169.  40.]
#  [188. 605. 195. 274. 154.]
#  [282. 241. 678. 118.  27.]
#  [215. 340. 270. 458. 132.]
#  [ 42. 233.  51. 183. 905.]]
# za parametre c= gini  i m= 5 weigth je: balanced  tacnost je:  0.45567677599377887  a mat. konf. je:
# [[539. 226. 368. 174.  39.]
#  [219. 567. 223. 261. 146.]
#  [267. 223. 724. 108.  24.]
#  [237. 320. 294. 439. 125.]
#  [ 50. 221.  62. 189. 892.]]
# za parametre c= gini  i m= 10 weigth je: None  tacnost je:  0.5209763339446336  a mat. konf. je:
# [[638. 153. 249. 258.  48.]
#  [191. 685. 149. 252. 139.]
#  [252. 185. 696. 178.  35.]
#  [228. 194. 205. 658. 130.]
#  [ 58. 200.  41. 178. 937.]]
# za parametre c= gini  i m= 10 weigth je: balanced  tacnost je:  0.5225609325032956  a mat. konf. je:
# [[662. 143. 239. 252.  50.]
#  [204. 646. 159. 253. 154.]
#  [232. 174. 718. 181.  41.]
#  [211. 200. 225. 651. 128.]
#  [ 53. 172.  49. 192. 948.]]
# za parametre c= gini  i m= 15 weigth je: None  tacnost je:  0.5056950734184164  a mat. konf. je:
# [[619. 166. 244. 251.  66.]
#  [184. 666. 170. 241. 155.]
#  [266. 181. 658. 193.  48.]
#  [234. 216. 200. 623. 142.]
#  [ 72. 199.  36. 165. 942.]]
# za parametre c= gini  i m= 15 weigth je: balanced  tacnost je:  0.50799451908962  a mat. konf. je:
# [[639. 154. 233. 248.  72.]
#  [173. 666. 167. 237. 173.]
#  [232. 191. 662. 207.  54.]
#  [220. 209. 226. 608. 152.]
#  [ 77. 177.  46. 165. 949.]]
# za parametre c= gini  i m= 20 weigth je: None  tacnost je:  0.49862623767522896  a mat. konf. je:
# [[623. 161. 236. 250.  76.]
#  [178. 651. 169. 254. 164.]
#  [268. 178. 634. 216.  50.]
#  [245. 212. 208. 597. 153.]
#  [ 70. 176.  53. 161. 954.]]
# za parametre c= gini  i m= 20 weigth je: balanced  tacnost je:  0.5061233994951574  a mat. konf. je:
# [[617. 167. 248. 247.  67.]
#  [172. 664. 175. 225. 180.]
#  [240. 169. 691. 205.  41.]
#  [228. 204. 228. 590. 165.]
#  [ 79. 183.  47. 156. 949.]]
# za parametre c= gini  i m= 35 weigth je: None  tacnost je:  0.49776210021166795  a mat. konf. je:
# [[622. 154. 256. 251.  63.]
#  [181. 646. 182. 239. 168.]
#  [266. 188. 634. 196.  62.]
#  [263. 204. 194. 605. 149.]
#  [ 71. 186.  57. 154. 946.]]
# za parametre c= gini  i m= 35 weigth je: balanced  tacnost je:  0.49675241505212686  a mat. konf. je:
# [[603. 173. 243. 259.  68.]
#  [172. 660. 188. 233. 163.]
#  [255. 177. 652. 216.  46.]
#  [238. 214. 208. 598. 157.]
#  [ 90. 182.  47. 162. 933.]]
# za parametre c= entropy  i m= 5 weigth je: None  tacnost je:  0.4605754955899048  a mat. konf. je:
# [[ 584.  197.  284.  222.   59.]
#  [ 210.  575.  160.  233.  238.]
#  [ 382.  165.  593.  128.   78.]
#  [ 260.  300.  235.  431.  189.]
#  [  58.  180.   48.  116. 1012.]]
# za parametre c= entropy  i m= 5 weigth je: balanced  tacnost je:  0.4601417634558844  a mat. konf. je:
# [[ 597.  190.  300.  191.   68.]
#  [ 214.  564.  161.  217.  260.]
#  [ 378.  171.  597.  128.   72.]
#  [ 269.  312.  240.  396.  198.]
#  [  63.  153.   51.  109. 1038.]]
# za parametre c= entropy  i m= 10 weigth je: None  tacnost je:  0.5143499631972255  a mat. konf. je:
# [[611. 178. 269. 236.  52.]
#  [187. 682. 156. 247. 144.]
#  [250. 170. 728. 164.  34.]
#  [257. 232. 186. 599. 141.]
#  [ 71. 170.  35. 190. 948.]]
# za parametre c= entropy  i m= 10 weigth je: balanced  tacnost je:  0.510748489422841  a mat. konf. je:
# [[612. 181. 267. 230.  56.]
#  [196. 652. 161. 260. 147.]
#  [254. 149. 737. 170.  36.]
#  [258. 239. 209. 585. 124.]
#  [ 71. 168.  39. 179. 957.]]
# za parametre c= entropy  i m= 15 weigth je: None  tacnost je:  0.5106008624740613  a mat. konf. je:
# [[600. 189. 242. 255.  60.]
#  [175. 689. 151. 226. 175.]
#  [234. 181. 687. 199.  45.]
#  [241. 230. 200. 599. 145.]
#  [ 74. 170.  39. 164. 967.]]
# za parametre c= entropy  i m= 15 weigth je: balanced  tacnost je:  0.5072890286146771  a mat. konf. je:
# [[618. 173. 250. 230.  75.]
#  [158. 689. 141. 258. 170.]
#  [267. 162. 657. 217.  43.]
#  [247. 221. 221. 578. 148.]
#  [ 69. 162.  45. 161. 977.]]
# za parametre c= entropy  i m= 20 weigth je: None  tacnost je:  0.5087314062818387  a mat. konf. je:
# [[602. 171. 253. 259.  61.]
#  [165. 656. 157. 269. 169.]
#  [218. 191. 686. 205.  46.]
#  [246. 236. 187. 609. 137.]
#  [ 73. 149.  42. 174. 976.]]
# za parametre c= entropy  i m= 20 weigth je: balanced  tacnost je:  0.5075788764549573  a mat. konf. je:
# [[623. 165. 250. 244.  64.]
#  [175. 654. 159. 274. 154.]
#  [244. 165. 666. 228.  43.]
#  [255. 241. 189. 593. 137.]
#  [ 61. 164.  40. 164. 985.]]
# za parametre c= entropy  i m= 35 weigth je: None  tacnost je:  0.5095918010903603  a mat. konf. je:
# [[592. 170. 274. 245.  65.]
#  [178. 664. 145. 259. 170.]
#  [247. 171. 690. 203.  35.]
#  [256. 220. 182. 620. 137.]
#  [ 67. 158.  44. 176. 969.]]
# za parametre c= entropy  i m= 35 weigth je: balanced  tacnost je:  0.5068577915840163  a mat. konf. je:
# [[615. 172. 248. 240.  71.]
#  [174. 668. 146. 261. 167.]
#  [259. 163. 675. 208.  41.]
#  [253. 223. 193. 592. 154.]
#  [ 74. 168.  41. 165. 966.]]
# najbolja tacnost je u iteraciji broj:  3

# %%
baze = [g0001,g0002,g0003,g0005,g1003,g1004,g1005,g1007,g1008,g1009,g1011,g1012,g1014,g1015,g1016,g1023,g1027,g1036,g1045,g1051,g1053,g1057,g1060]
labels_y = ['L', 'N', 'R', 'S', 'T']
acc = []
pca_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
for i in range(0,len(baze)):
  izbaci = baze[i].index
  obuka = bez_imena.drop(izbaci, axis = 0)
  test = baze[i]

  acc_tmp = []
  X_obuka29= obuka.iloc[:, :-1]
  y_obuka29 = obuka.iloc[:, -1]
  s = StandardScaler()
  XPCA_obuka29_std = s.fit_transform(X_obuka29)

  X_test1= test.iloc[:, :-1]
  y_test1 = test.iloc[:, -1]
  XPCA_test1_std = s.transform(X_test1)

  pca = PCA(n_components=125)
  pca.fit(XPCA_obuka29_std)
  X_train_PCA = pca.transform(XPCA_obuka29_std)
  X_test_PCA=pca.transform(XPCA_test1_std)

  classifier_kon = DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_depth=10)  
  classifier_kon.fit(X_train_PCA, y_obuka29)

  # testiranje
  y_pred_kon = classifier_kon.predict(X_test_PCA) 
  conf_mat_knn1 = confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  #print(conf_mat_knnSZ)
  
  #acc_tmp.append(accuracy_score(y_test1, y_pred_kon))
  pca_conf_mat += confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  
  print(pca_conf_mat)

#   [[486. 244. 247. 289.  80.]
#  [337. 281. 220. 330. 248.]
#  [330. 199. 482. 267.  68.]
#  [291. 301. 204. 438. 181.]
#  [ 98. 276.  57. 180. 803.]]
# Out:
# [[31.  6. 15.  5.  0.]
#  [ 9. 13. 28. 10.  0.]
#  [ 8. 10. 33.  6.  0.]
#  [16.  3. 17. 24.  0.]
#  [37.  5. 11.  5.  2.]]
# [[56. 22. 20. 15.  1.]
#  [28. 19. 37. 33.  3.]
#  [24. 21. 52. 14.  3.]
#  [25. 30. 18. 47.  0.]
#  [38. 48. 11.  9. 14.]]
# [[72. 29. 41. 27.  2.]
#  [38. 26. 45. 58. 13.]
#  [33. 26. 74. 35.  3.]
#  [32. 47. 33. 65.  3.]
#  [38. 55. 11. 14. 62.]]
# [[ 85.  33.  67.  41.   2.]
#  [ 45.  37.  61.  78.  19.]
#  [ 53.  28.  96.  48.   3.]
#  [ 60.  49.  43.  85.   3.]
#  [ 38.  62.  12.  19. 109.]]
# [[115.  38.  74.  50.   8.]
#  [ 71.  42.  76.  81.  30.]
#  [ 83.  30. 107.  57.   8.]
#  [ 77.  63.  49. 100.  11.]
#  [ 40.  67.  12.  19. 162.]]
# [[138.  47.  81.  61.  17.]
#  [ 91.  54.  87.  85.  45.]
#  [102.  35. 126.  67.  14.]
#  [ 79.  78.  58. 114.  33.]
#  [ 40.  82.  17.  24. 199.]]
# [[152.  77.  85.  70.  19.]
#  [ 94.  70.  91.  96.  73.]
#  [128.  37. 141.  82.  15.]
#  [ 83.  93.  69. 134.  45.]
#  [ 42.  97.  17.  32. 236.]]
# [[177.  79. 101.  86.  19.]
#  [103.  87.  95. 125.  76.]
#  [140.  37. 185.  85.  15.]
#  [105. 108.  74. 153.  46.]
#  [ 42. 102.  17.  34. 291.]]
# [[203.  92. 107.  98.  21.]
#  [128.  91. 115. 134.  80.]
#  [155.  47. 211.  92.  16.]
#  [130. 124.  82. 163.  49.]
#  [ 44. 127.  26.  37. 314.]]
# [[238.  94. 125. 102.  21.]
#  [152. 108. 128. 140.  82.]
#  [172.  50. 247.  95.  16.]
#  [141. 142.  94. 181.  52.]
#  [ 45. 134.  26.  49. 356.]]
# [[253. 115. 137. 113.  21.]
#  [163. 131. 132. 159.  87.]
#  [183.  72. 267. 101.  16.]
#  [146. 166. 103. 204.  53.]
#  [ 58. 168.  33.  51. 362.]]
# [[281. 118. 154. 121.  23.]
#  [177. 143. 150. 168.  96.]
#  [208.  79. 279. 115.  16.]
#  [178. 169. 119. 211.  56.]
#  [ 59. 174.  35.  62. 402.]]
# [[310. 126. 165. 130.  25.]
#  [195. 159. 153. 190.  99.]
#  [220.  80. 305. 135.  16.]
#  [195. 174. 135. 235.  56.]
#  [ 63. 186.  35.  77. 433.]]
# [[350. 126. 180. 134.  25.]
#  [218. 168. 160. 210. 102.]
#  [230.  82. 350. 137.  16.]
#  [217. 187. 141. 256.  56.]
#  [ 67. 194.  35.  78. 482.]]
# [[358. 131. 198. 157.  30.]
#  [229. 168. 161. 229. 133.]
#  [233.  91. 357. 163.  30.]
#  [221. 193. 144. 290.  71.]
#  [ 71. 196.  35. 123. 493.]]
# [[382. 141. 211. 169.  30.]
#  [255. 179. 180. 234. 134.]
#  [246.  95. 394. 168.  30.]
#  [242. 198. 170. 299.  72.]
#  [ 76. 207.  36. 132. 529.]]
# [[385. 160. 211. 185.  51.]
#  [255. 201. 180. 242. 166.]
#  [252. 121. 401. 177.  41.]
#  [242. 212. 170. 311. 108.]
#  [ 77. 211.  36. 132. 586.]]
# [[409. 162. 222. 207.  51.]
#  [275. 205. 188. 272. 166.]
#  [265. 132. 422. 191.  41.]
#  [259. 216. 180. 342. 108.]
#  [ 94. 223.  46. 148. 593.]]
# [[445. 168. 229. 215.  53.]
#  [303. 216. 202. 280. 167.]
#  [274. 133. 461. 201.  41.]
#  [275. 228. 189. 364. 111.]
#  [ 97. 234.  50. 150. 635.]]
# [[445. 218. 230. 220.  56.]
#  [303. 246. 207. 283. 191.]
#  [294. 158. 465. 206.  46.]
#  [275. 265. 196. 371. 122.]
#  [ 97. 257.  54. 155. 665.]]
# [[453. 226. 233. 243.  73.]
#  [305. 250. 207. 304. 226.]
#  [296. 181. 465. 220.  66.]
#  [276. 269. 196. 388. 162.]
#  [ 97. 264.  54. 174. 701.]]
# [[456. 238. 234. 280.  79.]
#  [319. 260. 213. 320. 242.]
#  [312. 191. 466. 250.  68.]
#  [285. 278. 201. 418. 171.]
#  [ 98. 271.  57. 177. 749.]]
# [[486. 244. 247. 289.  80.]
#  [337. 281. 220. 330. 248.]
#  [330. 199. 482. 267.  68.]
#  [291. 301. 204. 438. 181.]
#  [ 98. 276.  57. 180. 803.]]

# %%
L = evaluation_classif_L(pca_conf_mat)
N = evaluation_classif_N(pca_conf_mat)
R = evaluation_classif_R(pca_conf_mat)
S = evaluation_classif_S(pca_conf_mat)
T = evaluation_classif_T(pca_conf_mat)

prosecna_tacnost = (L[0]+N[0]+R[0]+S[0]+T[0])/5
print('PROSECNA TACNOST JE ', prosecna_tacnost)

prosecna_specificnost = (L[3]+N[3]+R[3]+S[3]+T[3])/5
print('PROSECNA specificnost JE ', prosecna_specificnost)

prosecna_preciznost = (L[1]+N[1]+R[1]+S[1]+T[1])/5
print('PROSECNA preciznost JE ', prosecna_preciznost)

prosecna_osetljivost = (L[2]+N[2]+R[2]+S[2]+T[2])/5
print('PROSECNA osetljivost JE ', prosecna_osetljivost)

# PROSECNA TACNOST JE  0.7435779155254434
# PROSECNA specificnost JE  0.8397296825716131
# PROSECNA preciznost JE  0.36052347374169713
# PROSECNA osetljivost JE  0.35900947443310083
# Out:
# PROSECNA TACNOST JE  0.7435779155254434
# PROSECNA specificnost JE  0.8397296825716131
# PROSECNA preciznost JE  0.36052347374169713
# PROSECNA osetljivost JE  0.35900947443310083

# %%
#ODABIR OPTIMALNIH PARAMETARA ZA KNN, LDA N_KOMP=4
labels_y = ['L', 'N', 'R', 'S', 'T']
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
    for m in [5,10,15,20,35]:
        for w in [None,'balanced']:
            indexes = kf.split(X_obuka, y_obuka)
            acc_tmp = []
            fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
            for train_index, test_index in indexes:
                    X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                    X_std_test = s.transform(X_obuka.iloc[test_index,:])
                    lda = LinearDiscriminantAnalysis(n_components=4)
                    lda.fit(X_std1,y_obuka.iloc[train_index])
                    X_train_r = lda.transform(X_std1)
                    X_test_r=lda.transform(X_std_test)
                    classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                    classifier.fit(X_train_r, y_obuka.iloc[train_index])
                    y_pred = classifier.predict(X_test_r)
                    acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                    fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
            print('za parametre  n_components= 4, k=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
            print(fin_conf_mat)
            acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za parametre  n_components= 4, k= gini  i m= 10 weigth je: None  tacnost je:  0.6769585521746906  a mat. konf. je:
# [[ 868.  121.  182.  145.   30.]
#  [  97.  983.   97.  118.  121.]
#  [ 149.  123.  893.  157.   24.]
#  [ 145.  149.  137.  860.  124.]
#  [  31.  154.   16.  121. 1092.]]
# Out:
# za parametre  n_components= 4, k= gini  i m= 5 weigth je: None  tacnost je:  0.6752290296958885  a mat. konf. je:
# [[ 852.  142.  181.  157.   14.]
#  [ 117.  991.  102.  103.  103.]
#  [ 137.  152.  885.  163.    9.]
#  [ 145.  148.  169.  854.   99.]
#  [  52.  123.   39.   98. 1102.]]
# za parametre  n_components= 4, k= gini  i m= 5 weigth je: balanced  tacnost je:  0.6722024693206249  a mat. konf. je:
# [[ 871.  116.  208.  139.   12.]
#  [ 117.  934.  128.  134.  103.]
#  [ 125.  133.  907.  175.    6.]
#  [ 147.  122.  193.  860.   93.]
#  [  45.  109.   54.  115. 1091.]]
# za parametre  n_components= 4, k= gini  i m= 10 weigth je: None  tacnost je:  0.6769585521746906  a mat. konf. je:
# [[ 868.  121.  182.  145.   30.]
#  [  97.  983.   97.  118.  121.]
#  [ 149.  123.  893.  157.   24.]
#  [ 145.  149.  137.  860.  124.]
#  [  31.  154.   16.  121. 1092.]]
# za parametre  n_components= 4, k= gini  i m= 10 weigth je: balanced  tacnost je:  0.6768080142719912  a mat. konf. je:
# [[ 880.  109.  189.  124.   44.]
#  [  99.  956.  108.  122.  131.]
#  [ 169.   99.  889.  165.   24.]
#  [ 159.  142.  140.  860.  114.]
#  [  33.  143.   18.  110. 1110.]]
# za parametre  n_components= 4, k= gini  i m= 15 weigth je: None  tacnost je:  0.6465426184446356  a mat. konf. je:
# [[ 828.  120.  194.  171.   33.]
#  [ 121.  915.  109.  143.  128.]
#  [ 185.  118.  845.  178.   20.]
#  [ 155.  172.  149.  808.  131.]
#  [  38.  141.   21.  125. 1089.]]
# za parametre  n_components= 4, k= gini  i m= 15 weigth je: balanced  tacnost je:  0.6449503266506149  a mat. konf. je:
# [[ 837.  117.  199.  148.   45.]
#  [ 120.  900.  120.  140.  136.]
#  [ 187.  107.  859.  170.   23.]
#  [ 175.  161.  163.  796.  120.]
#  [  33.  156.   23.  120. 1082.]]
# za parametre  n_components= 4, k= gini  i m= 20 weigth je: None  tacnost je:  0.6345806770878817  a mat. konf. je:
# [[ 809.  128.  207.  170.   32.]
#  [ 127.  871.  122.  155.  141.]
#  [ 192.  117.  836.  181.   20.]
#  [ 164.  164.  165.  798.  124.]
#  [  43.  142.   20.  121. 1088.]]
# za parametre  n_components= 4, k= gini  i m= 20 weigth je: balanced  tacnost je:  0.6342839677133625  a mat. konf. je:
# [[ 829.  119.  203.  153.   42.]
#  [ 123.  876.  126.  147.  144.]
#  [ 200.  115.  830.  176.   25.]
#  [ 179.  161.  170.  780.  125.]
#  [  36.  148.   22.  123. 1085.]]
# za parametre  n_components= 4, k= gini  i m= 35 weigth je: None  tacnost je:  0.6312621896195383  a mat. konf. je:
# [[ 818.  129.  201.  165.   33.]
#  [ 137.  855.  116.  161.  147.]
#  [ 203.  120.  819.  185.   19.]
#  [ 162.  168.  150.  809.  126.]
#  [  42.  142.   24.  128. 1078.]]
# za parametre  n_components= 4, k= gini  i m= 35 weigth je: balanced  tacnost je:  0.6335637145435415  a mat. konf. je:
# [[ 829.  106.  208.  155.   48.]
#  [ 129.  868.  121.  151.  147.]
#  [ 205.  109.  831.  176.   25.]
#  [ 176.  158.  167.  784.  130.]
#  [  36.  152.   20.  123. 1083.]]
# za parametre  n_components= 4, k= entropy  i m= 5 weigth je: None  tacnost je:  0.6700394226330826  a mat. konf. je:
# [[ 848.  113.  205.  151.   29.]
#  [ 131.  895.  143.  111.  136.]
#  [ 107.  124.  914.  187.   14.]
#  [ 157.  118.  170.  830.  140.]
#  [  20.  103.   23.  107. 1161.]]
# za parametre  n_components= 4, k= entropy  i m= 5 weigth je: balanced  tacnost je:  0.666867522487119  a mat. konf. je:
# [[ 829.  132.  213.  141.   31.]
#  [ 120.  893.  158.  105.  140.]
#  [ 108.  125.  923.  175.   15.]
#  [ 155.  139.  164.  813.  144.]
#  [  22.  104.   23.   97. 1168.]]
# za parametre  n_components= 4, k= entropy  i m= 10 weigth je: None  tacnost je:  0.6677312441001202  a mat. konf. je:
# [[ 860.  132.  185.  139.   30.]
#  [ 119.  962.   96.  117.  122.]
#  [ 171.  114.  877.  169.   15.]
#  [ 147.  160.  148.  833.  127.]
#  [  28.  149.   17.  120. 1100.]]
# za parametre  n_components= 4, k= entropy  i m= 10 weigth je: balanced  tacnost je:  0.6644148358845765  a mat. konf. je:
# [[ 854.  129.  192.  141.   30.]
#  [ 120.  927.  109.  128.  132.]
#  [ 176.  110.  885.  158.   17.]
#  [ 139.  160.  153.  829.  134.]
#  [  28.  129.   22.  121. 1114.]]
# za parametre  n_components= 4, k= entropy  i m= 15 weigth je: None  tacnost je:  0.6351514319814033  a mat. konf. je:
# [[ 824.  125.  196.  165.   36.]
#  [ 130.  875.  125.  156.  130.]
#  [ 205.  103.  842.  177.   19.]
#  [ 177.  164.  159.  779.  136.]
#  [  39.  147.   26.  116. 1086.]]
# za parametre  n_components= 4, k= entropy  i m= 15 weigth je: balanced  tacnost je:  0.6351539270847628  a mat. konf. je:
# [[ 832.  128.  200.  151.   35.]
#  [ 137.  872.  119.  157.  131.]
#  [ 212.  103.  834.  177.   20.]
#  [ 177.  167.  164.  774.  133.]
#  [  32.  142.   25.  121. 1094.]]
# za parametre  n_components= 4, k= entropy  i m= 20 weigth je: None  tacnost je:  0.6312565756369792  a mat. konf. je:
# [[ 818.  130.  201.  163.   34.]
#  [ 121.  884.  114.  158.  139.]
#  [ 204.  114.  823.  182.   23.]
#  [ 183.  170.  159.  767.  136.]
#  [  41.  147.   25.  114. 1087.]]
# za parametre  n_components= 4, k= entropy  i m= 20 weigth je: balanced  tacnost je:  0.6354400322700035  a mat. konf. je:
# [[ 827.  126.  199.  158.   36.]
#  [ 132.  891.  119.  139.  135.]
#  [ 210.  115.  828.  174.   19.]
#  [ 173.  169.  167.  766.  140.]
#  [  27.  141.   26.  124. 1096.]]
# za parametre  n_components= 4, k= entropy  i m= 35 weigth je: None  tacnost je:  0.6315441362991795  a mat. konf. je:
# [[ 815.  133.  199.  165.   34.]
#  [ 127.  883.  120.  156.  130.]
#  [ 218.  112.  813.  180.   23.]
#  [ 171.  162.  169.  773.  140.]
#  [  42.  142.   28.  105. 1097.]]
# za parametre  n_components= 4, k= entropy  i m= 35 weigth je: balanced  tacnost je:  0.6367395652698246  a mat. konf. je:
# [[ 836.  129.  191.  158.   32.]
#  [ 133.  890.  117.  144.  132.]
#  [ 212.  108.  826.  179.   21.]
#  [ 180.  169.  166.  765.  135.]
#  [  29.  136.   22.  127. 1100.]]
# najbolja tacnost je u iteraciji broj:  2

# %%
#ODABIR OPTIMALNIH PARAMETARA ZA KNN, LDA N_KOMP=3
labels_y = ['L', 'N', 'R', 'S', 'T']
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for c in ['gini', 'entropy']:
    for m in [5,10,15,20,35]:
        for w in [None,'balanced']:
            indexes = kf.split(X_obuka, y_obuka)
            acc_tmp = []
            fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
            for train_index, test_index in indexes:
                    X_std1 = s.fit_transform(X_obuka.iloc[train_index,:])
                    X_std_test = s.transform(X_obuka.iloc[test_index,:])
                    lda = LinearDiscriminantAnalysis(n_components=3)
                    lda.fit(X_std1,y_obuka.iloc[train_index])
                    X_train_r = lda.transform(X_std1)
                    X_test_r=lda.transform(X_std_test)
                    classifier = DecisionTreeClassifier(class_weight=w,criterion=c,max_depth=m)  
                    classifier.fit(X_train_r, y_obuka.iloc[train_index])
                    y_pred = classifier.predict(X_test_r)
                    acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                    fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
            print('za parametre  n_components= 3, k=', c, ' i m=', m, 'weigth je:',w,' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
            print(fin_conf_mat)
            acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# za parametre  n_components= 3, k= gini  i m= 5 weigth je: None  tacnost je:  0.6714768100935248  a mat. konf. je:
# [[8.750e+02 1.350e+02 1.540e+02 1.710e+02 1.100e+01]
#  [1.110e+02 1.007e+03 8.200e+01 1.120e+02 1.040e+02]
#  [1.240e+02 1.750e+02 7.820e+02 2.610e+02 4.000e+00]
#  [1.520e+02 1.430e+02 1.270e+02 8.990e+02 9.400e+01]
#  [3.400e+01 1.460e+02 1.000e+00 1.380e+02 1.095e+03]]
# Out:
# za parametre  n_components= 3, k= gini  i m= 5 weigth je: None  tacnost je:  0.6714768100935248  a mat. konf. je:
# [[8.750e+02 1.350e+02 1.540e+02 1.710e+02 1.100e+01]
#  [1.110e+02 1.007e+03 8.200e+01 1.120e+02 1.040e+02]
#  [1.240e+02 1.750e+02 7.820e+02 2.610e+02 4.000e+00]
#  [1.520e+02 1.430e+02 1.270e+02 8.990e+02 9.400e+01]
#  [3.400e+01 1.460e+02 1.000e+00 1.380e+02 1.095e+03]]
# za parametre  n_components= 3, k= gini  i m= 5 weigth je: balanced  tacnost je:  0.6674411883345601  a mat. konf. je:
# [[8.670e+02 1.230e+02 1.560e+02 1.890e+02 1.100e+01]
#  [1.250e+02 9.490e+02 9.500e+01 1.400e+02 1.070e+02]
#  [1.150e+02 1.510e+02 7.880e+02 2.880e+02 4.000e+00]
#  [1.540e+02 1.130e+02 1.250e+02 9.290e+02 9.400e+01]
#  [4.200e+01 1.290e+02 1.000e+00 1.450e+02 1.097e+03]]
# za parametre  n_components= 3, k= gini  i m= 10 weigth je: None  tacnost je:  0.6530261445247036  a mat. konf. je:
# [[ 855.  134.  171.  161.   25.]
#  [ 107.  940.  127.  110.  132.]
#  [ 162.  133.  831.  209.   11.]
#  [ 165.  135.  161.  835.  119.]
#  [  22.  180.    6.  137. 1069.]]
# za parametre  n_components= 3, k= gini  i m= 10 weigth je: balanced  tacnost je:  0.6570615583583883  a mat. konf. je:
# [[ 840.  132.  179.  172.   23.]
#  [  98.  937.  127.  111.  143.]
#  [ 139.  129.  856.  212.   10.]
#  [ 159.  129.  170.  842.  115.]
#  [  20.  169.   11.  131. 1083.]]
# za parametre  n_components= 3, k= gini  i m= 15 weigth je: None  tacnost je:  0.6106474377367749  a mat. konf. je:
# [[ 829.  136.  178.  179.   24.]
#  [ 140.  855.  151.  116.  154.]
#  [ 194.  149.  788.  200.   15.]
#  [ 192.  150.  212.  730.  131.]
#  [  27.  180.   18.  155. 1034.]]
# za parametre  n_components= 3, k= gini  i m= 15 weigth je: balanced  tacnost je:  0.6165533473890823  a mat. konf. je:
# [[ 830.  126.  173.  192.   25.]
#  [ 130.  867.  141.  134.  144.]
#  [ 179.  150.  802.  203.   12.]
#  [ 193.  150.  204.  736.  132.]
#  [  28.  171.   15.  158. 1042.]]
# za parametre  n_components= 3, k= gini  i m= 20 weigth je: None  tacnost je:  0.6017106012783245  a mat. konf. je:
# [[ 821.  127.  181.  187.   30.]
#  [ 131.  812.  159.  144.  170.]
#  [ 191.  156.  779.  203.   17.]
#  [ 199.  145.  203.  737.  131.]
#  [  31.  180.   15.  163. 1025.]]
# za parametre  n_components= 3, k= gini  i m= 20 weigth je: balanced  tacnost je:  0.6022853067521655  a mat. konf. je:
# [[ 807.  138.  164.  204.   33.]
#  [ 141.  833.  141.  153.  148.]
#  [ 184.  153.  777.  216.   16.]
#  [ 200.  147.  202.  726.  140.]
#  [  32.  173.   22.  152. 1035.]]
# za parametre  n_components= 3, k= gini  i m= 35 weigth je: None  tacnost je:  0.6021424620848251  a mat. konf. je:
# [[ 824.  127.  170.  193.   32.]
#  [ 144.  809.  158.  143.  162.]
#  [ 191.  155.  778.  207.   15.]
#  [ 195.  144.  207.  739.  130.]
#  [  29.  176.   16.  166. 1027.]]
# za parametre  n_components= 3, k= gini  i m= 35 weigth je: balanced  tacnost je:  0.599258122601062  a mat. konf. je:
# [[ 808.  148.  161.  201.   28.]
#  [ 141.  817.  144.  155.  159.]
#  [ 183.  150.  783.  214.   16.]
#  [ 199.  150.  211.  724.  131.]
#  [  32.  175.   22.  160. 1025.]]
# za parametre  n_components= 3, k= entropy  i m= 5 weigth je: None  tacnost je:  0.6667232223428189  a mat. konf. je:
# [[8.500e+02 1.190e+02 1.680e+02 1.890e+02 2.000e+01]
#  [1.260e+02 9.350e+02 9.200e+01 1.250e+02 1.380e+02]
#  [1.230e+02 1.440e+02 8.070e+02 2.610e+02 1.100e+01]
#  [1.500e+02 1.250e+02 1.280e+02 8.900e+02 1.220e+02]
#  [1.600e+01 1.300e+02 1.000e+00 1.240e+02 1.143e+03]]
# za parametre  n_components= 3, k= entropy  i m= 5 weigth je: balanced  tacnost je:  0.6677308282495602  a mat. konf. je:
# [[8.420e+02 1.240e+02 1.810e+02 1.780e+02 2.100e+01]
#  [1.220e+02 9.400e+02 9.200e+01 1.230e+02 1.390e+02]
#  [1.120e+02 1.460e+02 8.240e+02 2.520e+02 1.200e+01]
#  [1.550e+02 1.230e+02 1.370e+02 8.780e+02 1.220e+02]
#  [2.000e+01 1.250e+02 1.000e+00 1.200e+02 1.148e+03]]
# za parametre  n_components= 3, k= entropy  i m= 10 weigth je: None  tacnost je:  0.6484124904874184  a mat. konf. je:
# [[ 842.  126.  180.  178.   20.]
#  [ 113.  934.  124.  115.  130.]
#  [ 156.  145.  827.  206.   12.]
#  [ 153.  137.  173.  824.  128.]
#  [  18.  170.   14.  141. 1071.]]
# za parametre  n_components= 3, k= entropy  i m= 10 weigth je: balanced  tacnost je:  0.6458167512922556  a mat. konf. je:
# [[ 851.  125.  172.  174.   24.]
#  [ 126.  908.  135.  115.  132.]
#  [ 155.  136.  824.  213.   18.]
#  [ 158.  138.  167.  815.  137.]
#  [  22.  162.   14.  134. 1082.]]
# za parametre  n_components= 3, k= entropy  i m= 15 weigth je: None  tacnost je:  0.6048789666945286  a mat. konf. je:
# [[ 793.  143.  193.  193.   24.]
#  [ 145.  834.  159.  128.  150.]
#  [ 185.  148.  789.  203.   21.]
#  [ 181.  137.  211.  735.  151.]
#  [  34.  173.   18.  144. 1045.]]
# za parametre  n_components= 3, k= entropy  i m= 15 weigth je: balanced  tacnost je:  0.6064635652531906  a mat. konf. je:
# [[ 797.  140.  191.  195.   23.]
#  [ 142.  812.  160.  148.  154.]
#  [ 188.  149.  784.  206.   19.]
#  [ 181.  131.  200.  751.  152.]
#  [  30.  159.   18.  144. 1063.]]
# za parametre  n_components= 3, k= entropy  i m= 20 weigth je: None  tacnost je:  0.6009843182753846  a mat. konf. je:
# [[ 793.  138.  193.  195.   27.]
#  [ 149.  820.  157.  135.  155.]
#  [ 189.  147.  779.  212.   19.]
#  [ 193.  137.  210.  734.  141.]
#  [  35.  177.   20.  139. 1043.]]
# za parametre  n_components= 3, k= entropy  i m= 20 weigth je: balanced  tacnost je:  0.6035786019935876  a mat. konf. je:
# [[ 789.  143.  187.  203.   24.]
#  [ 142.  810.  163.  145.  156.]
#  [ 183.  146.  778.  219.   20.]
#  [ 183.  137.  187.  760.  148.]
#  [  33.  163.   21.  147. 1050.]]
# za parametre  n_components= 3, k= entropy  i m= 35 weigth je: None  tacnost je:  0.5995450594874226  a mat. konf. je:
# [[ 794.  136.  196.  195.   25.]
#  [ 156.  819.  149.  135.  157.]
#  [ 187.  148.  775.  216.   20.]
#  [ 193.  136.  206.  735.  145.]
#  [  33.  178.   19.  148. 1036.]]
# za parametre  n_components= 3, k= entropy  i m= 35 weigth je: balanced  tacnost je:  0.5991104956522824  a mat. konf. je:
# [[ 775.  143.  191.  212.   25.]
#  [ 144.  810.  158.  147.  157.]
#  [ 184.  150.  771.  222.   19.]
#  [ 187.  135.  192.  750.  151.]
#  [  31.  163.   19.  151. 1050.]]
# najbolja tacnost je u iteraciji broj:  0

# %%
baze = [g0001,g0002,g0003,g0005,g1003,g1004,g1005,g1007,g1008,g1009,g1011,g1012,g1014,g1015,g1016,g1023,g1027,g1036,g1045,g1051,g1053,g1057,g1060]
labels_y = ['L', 'N', 'R', 'S', 'T']
acc = []
LDA_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
for i in range(0,len(baze)):
  izbaci = baze[i].index
  obuka = bez_imena.drop(izbaci, axis = 0)
  test = baze[i]

  acc_tmp = []
  X_obuka29= obuka.iloc[:, :-1]
  y_obuka29 = obuka.iloc[:, -1]
  s = StandardScaler()
  XLDA_obuka29_std = s.fit_transform(X_obuka29)

  X_test1= test.iloc[:, :-1]
  y_test1 = test.iloc[:, -1]
  XLDA_test1_std = s.transform(X_test1)

  lda = LinearDiscriminantAnalysis(n_components=4)
  lda.fit(XLDA_obuka29_std, y_obuka29)
  X_train_29_lda = lda.transform(XLDA_obuka29_std)
  X_test_29_lda = lda.transform(XLDA_test1_std)

  classifier_kon = DecisionTreeClassifier(class_weight=None,criterion='gini',max_depth=10)
  classifier_kon.fit(X_train_29_lda, y_obuka29)

  # testiranje
  y_pred_kon = classifier_kon.predict(X_test_29_lda) 
  conf_mat_knn1 = confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  #print(conf_mat_knnSZ)
  
  #acc_tmp.append(accuracy_score(y_test1, y_pred_kon))
  LDA_conf_mat += confusion_matrix(y_test1, y_pred_kon, labels=labels_y)
  
  print(LDA_conf_mat)

#   [[580. 203. 224. 237. 102.]
#  [223. 504. 215. 216. 258.]
#  [275. 194. 621. 186.  70.]
#  [243. 240. 232. 468. 232.]
#  [ 54. 215.  74. 148. 923.]]
# Out:
# [[21.  4. 30.  2.  0.]
#  [ 2.  5. 51.  2.  0.]
#  [10.  0. 47.  0.  0.]
#  [10.  0. 38. 12.  0.]
#  [ 4. 10. 41.  5.  0.]]
# [[33. 38. 33.  2.  8.]
#  [ 5. 52. 54.  4.  5.]
#  [12. 44. 52.  3.  3.]
#  [12. 24. 38. 25. 21.]
#  [ 4. 17. 41. 14. 44.]]
# [[40. 42. 70. 11.  8.]
#  [ 9. 96. 57. 13.  5.]
#  [24. 55. 81.  8.  3.]
#  [16. 41. 67. 34. 22.]
#  [ 6. 26. 41. 24. 83.]]
# [[ 42.  51.  73.  54.   8.]
#  [ 11. 100.  66.  58.   5.]
#  [ 36.  55. 108.  26.   3.]
#  [ 27.  41.  77.  73.  22.]
#  [  6.  31.  41.  25. 137.]]
# [[ 98.  51.  74.  54.   8.]
#  [ 31. 131.  70.  59.   9.]
#  [ 77.  58. 120.  27.   3.]
#  [ 48.  48.  89.  84.  31.]
#  [  6.  31.  41.  25. 197.]]
# [[126.  65.  80.  59.  14.]
#  [ 33. 159.  82.  60.  28.]
#  [ 86.  88. 137.  28.   5.]
#  [ 50.  75.  89.  91.  57.]
#  [  7.  46.  45.  25. 239.]]
# [[169.  75.  84.  61.  14.]
#  [ 37. 200.  83.  66.  38.]
#  [114.  92. 164.  28.   5.]
#  [ 67.  92.  89. 110.  66.]
#  [  8.  62.  45.  26. 283.]]
# [[209.  84.  91.  64.  14.]
#  [ 45. 232.  85.  82.  42.]
#  [132.  99. 193.  33.   5.]
#  [ 87.  97.  94. 142.  66.]
#  [  9.  65.  45.  29. 338.]]
# [[246. 103.  94.  64.  14.]
#  [ 84. 251.  89.  82.  42.]
#  [159. 105. 214.  36.   7.]
#  [114. 124. 101. 142.  67.]
#  [ 12.  96.  45.  29. 366.]]
# [[276. 103. 121.  66.  14.]
#  [103. 263. 116.  83.  45.]
#  [162. 105. 269.  37.   7.]
#  [118. 129. 126. 157.  80.]
#  [ 18.  96.  45.  48. 403.]]
# [[330. 104. 123.  68.  14.]
#  [103. 282. 116. 110.  61.]
#  [174. 107. 312.  39.   7.]
#  [133. 144. 138. 177.  80.]
#  [ 42. 102.  59.  65. 404.]]
# [[351. 114. 126.  88.  18.]
#  [110. 316. 124. 110.  74.]
#  [181. 114. 353.  42.   7.]
#  [137. 153. 149. 207.  87.]
#  [ 42. 108.  61.  72. 449.]]
# [[391. 130. 129.  88.  18.]
#  [128. 345. 126. 121.  76.]
#  [195. 122. 383.  49.   7.]
#  [162. 164. 153. 228.  88.]
#  [ 43. 125.  61.  75. 490.]]
# [[416. 131. 156.  94.  18.]
#  [129. 356. 163. 129.  81.]
#  [196. 122. 433.  57.   7.]
#  [164. 165. 173. 267.  88.]
#  [ 43. 131.  64.  76. 542.]]
# [[429. 131. 166. 129.  19.]
#  [135. 358. 163. 149. 115.]
#  [198. 132. 438.  93.  13.]
#  [165. 167. 173. 309. 105.]
#  [ 44. 131.  64.  80. 599.]]
# [[458. 137. 184. 134.  20.]
#  [146. 386. 179. 155. 116.]
#  [204. 143. 477.  96.  13.]
#  [179. 182. 197. 318. 105.]
#  [ 44. 162.  65.  86. 623.]]
# [[458. 138. 184. 134.  78.]
#  [146. 392. 179. 160. 167.]
#  [205. 144. 478. 122.  43.]
#  [179. 183. 197. 319. 165.]
#  [ 44. 163.  65.  86. 684.]]
# [[486. 142. 191. 152.  80.]
#  [151. 405. 199. 184. 167.]
#  [209. 146. 514. 138.  44.]
#  [188. 185. 205. 358. 169.]
#  [ 47. 175.  71. 123. 688.]]
# [[500. 143. 213. 173.  81.]
#  [161. 425. 209. 199. 174.]
#  [212. 146. 562. 146.  44.]
#  [191. 194. 209. 399. 174.]
#  [ 47. 175.  71. 127. 746.]]
# [[503. 190. 219. 174.  83.]
#  [161. 479. 210. 199. 181.]
#  [212. 180. 586. 147.  44.]
#  [191. 234. 216. 409. 179.]
#  [ 47. 210.  72. 128. 771.]]
# [[506. 203. 220. 197. 102.]
#  [162. 498. 210. 205. 217.]
#  [213. 194. 591. 161.  69.]
#  [191. 240. 216. 414. 230.]
#  [ 47. 213.  72. 130. 828.]]
# [[521. 203. 224. 237. 102.]
#  [164. 502. 214. 216. 258.]
#  [219. 194. 621. 183.  70.]
#  [195. 240. 232. 454. 232.]
#  [ 47. 213.  73. 135. 884.]]
# [[580. 203. 224. 237. 102.]
#  [223. 504. 215. 216. 258.]
#  [275. 194. 621. 186.  70.]
#  [243. 240. 232. 468. 232.]
#  [ 54. 215.  74. 148. 923.]]

# %%
L = evaluation_classif_L(LDA_conf_mat)
N = evaluation_classif_N(LDA_conf_mat)
R = evaluation_classif_R(LDA_conf_mat)
S = evaluation_classif_S(LDA_conf_mat)
T = evaluation_classif_T(LDA_conf_mat)

prosecna_tacnost = (L[0]+N[0]+R[0]+S[0]+T[0])/5
print('PROSECNA TACNOST LDA JE ', prosecna_tacnost)

prosecna_specificnost = (L[3]+N[3]+R[3]+S[3]+T[3])/5
print('PROSECNA specificnost LDA JE ', prosecna_specificnost)

prosecna_preciznost = (L[1]+N[1]+R[1]+S[1]+T[1])/5
print('PROSECNA preciznost LDA JE ', prosecna_preciznost)

prosecna_osetljivost = (L[2]+N[2]+R[2]+S[2]+T[2])/5
print('PROSECNA osetljivost LDA JE ', prosecna_osetljivost)

# PROSECNA TACNOST LDA JE  0.7785209744846476
# PROSECNA specificnost LDA JE  0.8615708470535794
# PROSECNA preciznost LDA JE  0.4406708709991619
# PROSECNA osetljivost LDA JE  0.4463411576981079
# Out:
# PROSECNA TACNOST LDA JE  0.7785209744846476
# PROSECNA specificnost LDA JE  0.8615708470535794
# PROSECNA preciznost LDA JE  0.4406708709991619
# PROSECNA osetljivost LDA JE  0.4463411576981079
