# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score,recall_score,f1_score
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

# %%
def evaluation_classif_L(conf_mat):
    TP = conf_mat[0,0]
    FP = conf_mat[1,0]+conf_mat[2,0]+conf_mat[3,0]+conf_mat[4,0]
    FN = conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[0,4]
    TN = conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[1,4]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[2,4]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_N(conf_mat):
    TP = conf_mat[1,1]
    FP = conf_mat[0,1]+conf_mat[2,1]+conf_mat[3,1]+conf_mat[4,1]
    FN = conf_mat[1,0]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[1,4]
    TN = conf_mat[0,0]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[0,4]+conf_mat[2,0]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[2,4]+conf_mat[3,0]+conf_mat[3,2]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,0]+conf_mat[4,2]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_R(conf_mat):
    TP = conf_mat[2,2]
    FP = conf_mat[0,2]+conf_mat[1,2]+conf_mat[3,2]+conf_mat[4,2]
    FN = conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,3]+conf_mat[2,4]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,3]+conf_mat[0,4]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,3]+conf_mat[1,4]+conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,3]+conf_mat[3,4]+conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,3]+conf_mat[4,4]
    
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_S(conf_mat):
    TP = conf_mat[3,3]
    FP = conf_mat[0,3]+conf_mat[1,3]+conf_mat[2,3]+conf_mat[4,3]
    FN = conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,4]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,4]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,4]+conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,4]+conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,4]
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
def evaluation_classif_T(conf_mat):
    TP = conf_mat[4,4]
    FP = conf_mat[0,4]+conf_mat[1,4]+conf_mat[2,4]+conf_mat[3,4]
    FN = conf_mat[4,0]+conf_mat[4,1]+conf_mat[4,2]+conf_mat[4,3]
    TN = conf_mat[0,0]+conf_mat[0,1]+conf_mat[0,2]+conf_mat[0,3]+conf_mat[1,0]+conf_mat[1,1]+conf_mat[1,2]+conf_mat[1,3]+conf_mat[2,0]+conf_mat[2,1]+conf_mat[2,2]+conf_mat[2,3]+conf_mat[3,0]+conf_mat[3,1]+conf_mat[3,2]+conf_mat[3,3]
    accuracy = (TP+TN)/(TP+TN+FP+FN)
    precision = TP/(TP+FP)
    sensitivity = TP/(TP+FN)
    specificity = TN/(TN+FP)
    

    return accuracy, precision, sensitivity, specificity

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#dataset_obuka_poc = pd.read_csv('drive/My Drive/diplomski2021/svi_preimenovani.csv')
dataset_obuka_poc = pd.read_csv('svi_preimenovani.csv', header=0)
print(dataset_obuka_poc.shape)

dataset_obuka_poc.head()
# Out:
# Mounted at /content/drive
# (9015, 386)
#                    name  pcm_RMSenergy_sma_max  ...  F0_sma_de_kurtosis  class
# 0  '1BMZD01L__1100.wav'               0.126734  ...            5.684139      ?
# 1  '1BMZD02L__1100.wav'               0.104423  ...            6.739047      ?
# 2  '1BMZD03L__1100.wav'               0.115782  ...            5.404254      ?
# 3  '1BMZD04L__1100.wav'               0.109434  ...            5.881023      ?
# 4  '1BMZD05L__1100.wav'               0.113291  ...            6.588470      ?
#
# [5 rows x 386 columns]

# %%
dataset_obuka_poc.loc[0:1752, 'class'] = 'L'
dataset_obuka_poc.loc[1753:3588, 'class'] = 'N'
dataset_obuka_poc.loc[3589:5341, 'class'] = 'R'
dataset_obuka_poc.loc[5342:7177, 'class'] = 'T'
dataset_obuka_poc.loc[7178:9016, 'class'] = 'S'

# %%
lista_izbaci = ['1052', '1101','1102','1103','1104','1105','1100']
indeksi_izbaci = []
for i in range(0, len(lista_izbaci)):    
    indeksi1 = dataset_obuka_poc.loc[dataset_obuka_poc['name'].str.find(lista_izbaci[i]) !=-1].index
    dataset_obuka_poc.drop(indeksi1, axis = 0, inplace = True)
dataset_obuka = dataset_obuka_poc
print(dataset_obuka.head())
print(dataset_obuka.shape)
# Out:
#                           name  ...  class
# 348  '1_0_0_MMMD01L__0001.wav'  ...      L
# 349  '1_0_0_MMMD01L__0002.wav'  ...      L
# 350  '1_0_0_MMMD01L__0003.wav'  ...      L
# 351  '1_0_0_MMMD01L__0005.wav'  ...      L
# 352  '1_0_0_MMMD01L__1003.wav'  ...      L
#
# [5 rows x 386 columns]
# (6937, 386)

# %%
X_obuka= dataset_obuka.iloc[:, :-1]
y_obuka = dataset_obuka.iloc[:, -1]

# %%
dataset_obuka.drop(['pcm_RMSenergy_sma_minPos','pcm_zcr_sma_maxPos','voiceProb_sma_minPos', 'F0_sma_min','F0_sma_minPos'],axis = 1,inplace = True)
print(dataset_obuka.shape)
# Out:
# (6937, 381)

# %%
bez_imena = dataset_obuka.drop(['name'], axis = 1)
print(bez_imena.shape)
# Out:
# (6937, 380)

# %%
X_obuka= bez_imena.iloc[:, :-1]
y_obuka = bez_imena.iloc[:, -1]
print(X_obuka.head())
# Out:
#      pcm_RMSenergy_sma_max  ...  F0_sma_de_kurtosis
# 348               0.024221  ...            4.763613
# 349               0.017863  ...           12.084200
# 350               0.020618  ...            7.861353
# 351               0.031197  ...            5.890788
# 352               0.082126  ...            8.007851
#
# [5 rows x 379 columns]

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'hidden_layer_sizes':((256,256), (256,256,256),(256,256,256,256),(512,512),(512,512,512),(512,512,512,512)), 'activation':['tanh','relu'],
'solver':['adam','sgd'], 'batch_size':[8,16], 'learning_rate': ['constant', 'invscaling', 'adaptive'], 'max_iter':[25,50,100,125,150]}
svm = SVC()
clf_svm=GridSearchCV(svm, parameters,cv = 10)
clf_svm.fit(X_std, y_obuka)
print(clf_svm.best_score_)
print(clf_svm.best_params_)

# %%
s = StandardScaler()
print(s)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
labels_y = ['L', 'N', 'R', 'S', 'T']
st = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []
for h in [(256,256), (256,256,256),(256,256,256,256),(512,512),(512,512,512),(512,512,512,512)]:
     for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [30,50,100,200]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [25,50,75,100,125]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= h, activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=', h, ' i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f085e6f498ff> in <module>()
#       1 labels_y = ['L', 'N', 'R', 'S', 'T']
# ----> 2 st = StandardScaler()
#       3 kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
#       4 acc = []
#       5 for h in [(256,256), (256,256,256),(256,256,256,256),(512,512),(512,512,512),(512,512,512,512)]:
#
# NameError: name 'StandardScaler' is not defined

# %%
labels_y = ['L', 'N', 'R', 'S', 'T']
st = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []         

for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (256,256), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=(256,256), i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  constant max_iter= 20 solver=  adam  tacnost je:  0.853103284803573  a mat. konf. je:
# [[1.122e+03 3.700e+01 9.500e+01 7.700e+01 1.500e+01]
#  [3.300e+01 1.231e+03 4.600e+01 5.100e+01 5.500e+01]
#  [7.800e+01 5.200e+01 1.126e+03 8.200e+01 8.000e+00]
#  [7.000e+01 5.800e+01 9.000e+01 1.138e+03 5.900e+01]
#  [8.000e+00 5.000e+01 1.000e+00 5.400e+01 1.301e+03]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  constant max_iter= 50 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  constant max_iter= 100 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  constant max_iter= 150 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 20 solver=  adam  tacnost je:  0.853103284803573  a mat. konf. je:
# [[1.122e+03 3.700e+01 9.500e+01 7.700e+01 1.500e+01]
#  [3.300e+01 1.231e+03 4.600e+01 5.100e+01 5.500e+01]
#  [7.800e+01 5.200e+01 1.126e+03 8.200e+01 8.000e+00]
#  [7.000e+01 5.800e+01 9.000e+01 1.138e+03 5.900e+01]
#  [8.000e+00 5.000e+01 1.000e+00 5.400e+01 1.301e+03]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 50 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 100 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 150 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 20 solver=  adam  tacnost je:  0.853103284803573  a mat. konf. je:
# [[1.122e+03 3.700e+01 9.500e+01 7.700e+01 1.500e+01]
#  [3.300e+01 1.231e+03 4.600e+01 5.100e+01 5.500e+01]
#  [7.800e+01 5.200e+01 1.126e+03 8.200e+01 8.000e+00]
#  [7.000e+01 5.800e+01 9.000e+01 1.138e+03 5.900e+01]
#  [8.000e+00 5.000e+01 1.000e+00 5.400e+01 1.301e+03]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 50 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 100 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# ['L' 'L' 'R' 'N' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'R' 'R' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N'
#  'N' 'T' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'N' 'L' 'R' 'R' 'R' 'S' 'R' 'R' 'S' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'T' 'R' 'R'
#  'R' 'R' 'R' 'T' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'S'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'S' 'N' 'S' 'S'
#  'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'L' 'S' 'L' 'S' 'S' 'S' 'R'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'S' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'T' 'R' 'L' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 150 solver=  adam  tacnost je:  0.865356113627007  a mat. konf. je:
# [[1140.   40.   82.   72.   12.]
#  [  31. 1262.   38.   40.   45.]
#  [  74.   49. 1139.   76.    8.]
#  [  64.   57.   86. 1153.   55.]
#  [   8.   46.    3.   48. 1309.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S'
#  'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'N' 'L' 'N' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'S' 'S' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'T' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'L' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'N' 'N' 'N' 'L' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
# ...
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'N' 'T' 'T' 'S' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'L' 'T' 'N'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N'
#  'T' 'N' 'T' 'T' 'S' 'T' 'T' 'N' 'R' 'R' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T' 'T' 'T' 'S' 'T' 'S' 'T' 'N' 'S' 'S'
#  'S' 'R' 'S' 'N' 'S' 'S' 'S' 'S' 'T' 'N' 'R' 'S' 'S' 'L' 'T' 'S' 'S' 'R'
#  'S' 'S' 'L' 'S' 'T' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'N' 'S' 'S' 'N' 'N'
#  'S' 'N' 'T' 'S' 'S' 'S' 'L' 'S' 'T' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'T'
#  'S' 'S' 'N' 'S' 'T' 'S' 'S' 'S' 'T' 'S' 'T' 'R' 'S' 'L' 'S' 'N' 'S' 'S'
#  'R' 'R' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'N' 'R' 'L' 'S' 'S' 'S' 'L'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'T' 'S' 'S' 'L' 'S' 'R' 'S'
#  'S' 'T' 'S' 'S' 'S' 'R' 'S' 'R' 'T' 'S' 'N' 'L' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'R' 'S' 'L' 'N' 'T' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 100 solver=  sgd  tacnost je:  0.6732090356009663  a mat. konf. je:
# [[ 890.  109.  175.  140.   32.]
#  [ 106.  890.  113.  112.  195.]
#  [ 164.  101.  911.  131.   39.]
#  [ 141.  156.  128.  833.  157.]
#  [  28.  138.   20.   82. 1146.]]
# ['L' 'L' 'R' 'L' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'R' 'L' 'S' 'R' 'L' 'L' 'L' 'L' 'R' 'R' 'R' 'L' 'R' 'L' 'L' 'L'
#  'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'S' 'S' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'R' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'L' 'S' 'L' 'S' 'L' 'R' 'R' 'L' 'L' 'N' 'L' 'R' 'L' 'L' 'N' 'L'
#  'L' 'T' 'L' 'L' 'L' 'L' 'N' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'R' 'L' 'R' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'R' 'N' 'S' 'S' 'N' 'N' 'T' 'N' 'L' 'T' 'R' 'N' 'N' 'N' 'N' 'R' 'S'
#  'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'L' 'T' 'R' 'R' 'N' 'N' 'N'
#  'N' 'T' 'T' 'N' 'R' 'S' 'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'L' 'N' 'S' 'N'
#  'N' 'N' 'T' 'R' 'T' 'T' 'N' 'N' 'N' 'N' 'N' 'N' 'T' 'N' 'N' 'L' 'N' 'T'
#  'N' 'T' 'S' 'N' 'T' 'N' 'N' 'S' 'T' 'N' 'N' 'N' 'L' 'N' 'L' 'L' 'L' 'T'
#  'N' 'N' 'N' 'N' 'N' 'L' 'N' 'L' 'N' 'N' 'N' 'L' 'N' 'R' 'L' 'N' 'N' 'N'
#  'N' 'R' 'S' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'R' 'S' 'S' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R'
#  'R' 'R' 'R' 'S' 'T' 'T' 'R' 'L' 'R' 'L' 'R' 'R' 'N' 'R' 'R' 'L' 'R' 'L'
#  'T' 'L' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'L' 'R' 'S' 'L' 'R'
#  'S' 'R' 'R' 'R' 'R' 'N' 'R' 'S' 'S' 'R' 'R' 'L' 'R' 'L' 'S' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'N' 'N' 'S' 'R' 'R'
#  'R' 'R' 'N' 'R' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'N' 'R' 'R' 'N' 'R' 'R' 'N' 'R' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'T' 'T'
#  'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'N' 'T' 'T' 'S' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'L' 'T' 'N'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'N'
#  'T' 'N' 'T' 'T' 'S' 'T' 'T' 'N' 'R' 'R' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'N' 'T' 'T' 'T' 'T' 'T' 'N' 'N' 'T' 'T' 'T' 'S' 'T' 'S' 'T' 'N' 'S' 'S'
#  'S' 'R' 'S' 'N' 'S' 'S' 'S' 'S' 'T' 'N' 'R' 'S' 'S' 'L' 'T' 'S' 'S' 'R'
#  'S' 'S' 'L' 'S' 'T' 'S' 'S' 'S' 'S' 'N' 'R' 'S' 'S' 'N' 'S' 'S' 'N' 'N'
#  'S' 'N' 'T' 'S' 'S' 'S' 'L' 'S' 'T' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'T'
#  'S' 'S' 'N' 'S' 'T' 'S' 'S' 'S' 'T' 'S' 'T' 'R' 'S' 'L' 'S' 'N' 'S' 'S'
#  'R' 'R' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'N' 'N' 'R' 'L' 'S' 'S' 'S' 'L'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'T' 'S' 'S' 'L' 'S' 'R' 'S'
#  'S' 'T' 'S' 'S' 'S' 'R' 'S' 'R' 'T' 'S' 'N' 'L' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'R' 'S' 'L' 'N' 'T' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  invscaling max_iter= 150 solver=  sgd  tacnost je:  0.6732090356009663  a mat. konf. je:
# [[ 890.  109.  175.  140.   32.]
#  [ 106.  890.  113.  112.  195.]
#  [ 164.  101.  911.  131.   39.]
#  [ 141.  156.  128.  833.  157.]
#  [  28.  138.   20.   82. 1146.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'R' 'L' 'L' 'L' 'R' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'L' 'L'
#  'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'N' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'N' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'R' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'L' 'L' 'L' 'L' 'N' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'R' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'S' 'N' 'L' 'S' 'N' 'N' 'N' 'N' 'N' 'R' 'N'
#  'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N'
#  'N' 'T' 'T' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'S' 'N' 'N' 'L' 'N' 'R' 'N' 'L' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'R' 'N' 'N' 'N' 'N' 'R' 'N' 'T' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'S' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'L' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'L' 'R' 'R'
#  'N' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'N' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'L' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'S' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'R' 'S' 'R' 'L' 'R' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'N' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'L' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'N' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'L' 'T' 'T' 'T' 'T' 'S' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'S' 'T' 'S' 'T' 'N' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'R' 'S' 'L' 'T' 'S' 'S' 'R'
#  'S' 'S' 'R' 'S' 'S' 'S' 'S' 'R' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'T' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'N' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'R' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'T'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'S' 'R' 'S' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 20 solver=  sgd  tacnost je:  0.826002927587942  a mat. konf. je:
# [[1080.   55.   98.  101.   12.]
#  [  46. 1184.   64.   57.   65.]
#  [ 102.   55. 1094.   86.    9.]
#  [  79.   76.   83. 1100.   77.]
#  [   9.   71.    5.   57. 1272.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ['L' 'L' 'R' 'L' 'L' 'L' 'R' 'T' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'L' 'L' 'L' 'N' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'R' 'S' 'L' 'L'
#  'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'N' 'L' 'L' 'L' 'L' 'T'
#  'L' 'L' 'L' 'L' 'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'N' 'L' 'R' 'L' 'L'
#  'L' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'R' 'L' 'L' 'T' 'L' 'R' 'L' 'L' 'L' 'L'
#  'L' 'S' 'L' 'L' 'L' 'L' 'N' 'L' 'L' 'S' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L'
#  'L' 'R' 'L' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'T' 'L' 'L' 'L' 'L' 'L'
#  'S' 'L' 'R' 'L' 'L' 'L' 'L' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L'
#  'N' 'N' 'N' 'S' 'N' 'N' 'N' 'T' 'N' 'L' 'S' 'N' 'N' 'N' 'N' 'N' 'R' 'N'
#  'R' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N' 'N' 'N' 'R' 'N' 'N' 'N'
#  'N' 'T' 'T' 'N' 'L' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'S' 'N' 'N' 'T'
#  'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'N' 'L' 'N' 'N'
#  'S' 'N' 'N' 'L' 'N' 'R' 'N' 'L' 'N' 'N' 'N' 'L' 'N' 'N' 'L' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'N' 'R' 'N' 'T' 'N' 'N' 'N' 'R' 'N' 'N' 'N' 'N' 'N'
#  'N' 'N' 'N' 'N' 'N' 'S' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'L' 'R' 'R' 'S' 'N' 'T' 'R' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'L' 'R' 'R'
#  'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'L' 'R'
#  'R' 'R' 'R' 'R' 'R' 'R' 'R' 'S' 'S' 'R' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'R' 'S' 'R' 'R' 'R' 'R' 'L' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'L' 'R' 'S' 'R' 'L' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R' 'R'
#  'R' 'R' 'S' 'R' 'R' 'R' 'R' 'R' 'N' 'R' 'R' 'R' 'L' 'R' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'N' 'T' 'T' 'N' 'N' 'S' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'L' 'T' 'T' 'T' 'T' 'S' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'T' 'T' 'R' 'T' 'N' 'T' 'T' 'T' 'T' 'T' 'T' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'S' 'N' 'T' 'T' 'T' 'S' 'T' 'S' 'T' 'N' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'R' 'S' 'S' 'T' 'S' 'S' 'R'
#  'S' 'S' 'R' 'S' 'S' 'S' 'S' 'R' 'S' 'N' 'R' 'S' 'S' 'S' 'S' 'S' 'T' 'S'
#  'S' 'L' 'T' 'S' 'S' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'T'
#  'S' 'S' 'N' 'S' 'T' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'L' 'S' 'N' 'S' 'R'
#  'R' 'R' 'S' 'S' 'S' 'T' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'S'
#  'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S' 'R' 'N'
#  'S' 'T' 'S' 'S' 'S' 'S' 'S' 'N' 'S' 'S' 'S' 'S' 'S' 'S' 'R' 'S' 'S' 'S'
#  'S' 'S' 'S' 'R' 'S' 'S' 'S' 'S' 'S']
# za parametre hidden=(256,256), i act= tanh batch je: 8 learn_rate=  adaptive max_iter= 50 solver=  sgd  tacnost je:  0.8268687284537428  a mat. konf. je:
# [[1073.   54.  103.  103.   13.]
#  [  46. 1186.   63.   55.   66.]
#  [  99.   52. 1101.   86.    8.]
#  [  78.   79.   83. 1101.   74.]
#  [   9.   64.    7.   59. 1275.]]
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
labels_y = ['L', 'N', 'R', 'S', 'T']
st = StandardScaler()
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
acc = []  
for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (256,256,256), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=3 i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6619216b98fc> in <module>()
#       1 labels_y = ['L', 'N', 'R', 'S', 'T']
# ----> 2 st = StandardScaler()
#       3 kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
#       4 acc = []
#       5 for a in ['tanh', 'relu']:
#
# NameError: name 'StandardScaler' is not defined

# %%
for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (256,256,256,256), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=', h, ' i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# %%
for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (512,512), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=', h, ' i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# %%
for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (512,512,512), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=', h, ' i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))

# %%
for a in ['tanh', 'relu']:
         for s in ['adam','sgd']:
            for b in [8,16]:
              for l in ['constant', 'invscaling', 'adaptive']:
                for m in [20,50,100,150]:
                    indexes = kf.split(X_obuka, y_obuka)
                    acc_tmp = []
                    fin_conf_mat = np.zeros((len(np.unique(y_obuka)),len(np.unique(y_obuka))))
                    for train_index, test_index in indexes:
                          X_std1 = st.fit_transform(X_obuka.iloc[train_index,:])  
                          X_std_test = st.transform(X_obuka.iloc[test_index,:])
                          classifier = MLPClassifier(hidden_layer_sizes= (512,512,512,512), activation=a,solver=s, batch_size=b, learning_rate=l, learning_rate_init=0.001, max_iter=m, shuffle=True,random_state=42, early_stopping=True, n_iter_no_change=10,validation_fraction=0.1, verbose=False) 
                          classifier.fit(X_std1, y_obuka.iloc[train_index])
                          y_pred = classifier.predict(X_std_test)
                          acc_tmp.append(accuracy_score(y_obuka.iloc[test_index], y_pred))
                          fin_conf_mat += confusion_matrix(y_obuka.iloc[test_index], y_pred, labels=labels_y)
                    print(y_pred)
                    print('za parametre hidden=', h, ' i act=', a, 'batch je:',b, 'learn_rate= ', l,'max_iter=',m,'solver= ',s, ' tacnost je: ', np.mean(acc_tmp), ' a mat. konf. je:')
                    print(fin_conf_mat)
                    acc.append(np.mean(acc_tmp))
print('najbolja tacnost je u iteraciji broj: ', np.argmax(acc))
